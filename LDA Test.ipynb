# %%
# Topic modeling is a type of statistical modeling for discovering the abstract “topics” that occur in a collection of documents. Latent Dirichlet Allocation (LDA) is an example of topic model and is used to classify text in a document to a particular topic. 
# It builds a topic per document model and words per topic model, modeled as Dirichlet distributions.
import numpy as np
import pandas as pd
import nltk
import gensim

# %%
data = pd.read_csv('news-data.csv', error_bad_lines=False);
data_text = data[['content']]
data_text['index'] = data_text.index
documents = data_text
documents = data_text[:6000]
# Out:
# c:\users\owner\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (0,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# c:\users\owner\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print("Number of articles:", len(documents))
print(documents[:5])
# Out:
# Number of articles: 6000
#                                              content  index
# 0        And never more so than in Showtime’s new...      0
# 1        AlphaGo’s victory isn’t a defeat for hum...      1
# 2        Super Deluxe built a weird internet empi...      2
# 3        Steven Yang quit his job at Google in th...      3
# 4        Ahead of Black Panther’s 2018 theatrical...      4

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Functions that perform lemmatization and stemming as part of preprocessing
def lemmatize_stemming(text):
    return SnowballStemmer("english").stem(WordNetLemmatizer().lemmatize(text, pos='v'))
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
#Selects the first article to compare before and after preprocessing
doc_sample = documents[documents['index'] == 0].values[0][0]
print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words[:20])
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample)[:20])
# Out:
# original document:
# ['', '', '', '', '', '', 'And', 'never', 'more', 'so', 'than', 'in', 'Showtime’s', 'new', 'series', 'revival', 'Some', 'spoilers', 'ahead', 'through']
#
#
#  tokenized and lemmatized document:
# ['showtim', 'seri', 'reviv', 'spoiler', 'ahead', 'episod', 'season', 'twin', 'peak', 'showtim', 'bring', 'david', 'lynch', 'groundbreak', 'seri', 'twin', 'peak', 'fulfil', 'propheci', 'process']

# %%
#All the preprocessed articles
processed_docs = documents['content'].map(preprocess)
processed_docs[:10]
# Out:
# 0    [showtim, seri, reviv, spoiler, ahead, episod,...
# 1    [alphago, victori, defeat, human, opportun, lo...
# 2    [super, delux, build, weird, internet, empir, ...
# 3    [steven, yang, quit, googl, summer, build, pro...
# 4    [ahead, black, panther, theatric, releas, marv...
# 5    [facebook, instant, articl, promis, transform,...
# 6    [weapon, weapon, year, artist, technolog, enth...
# 7    [insid, busi, imagin, futur, dubai, world, loo...
# 8    [legal, threat, disgruntl, client, insid, uber...
# 9    [genius, quiet, lay, bunch, engin, surviv, med...
# Name: content, dtype: object

# %%
#Dictionary that contains the number of times a word appears
dictionary = gensim.corpora.Dictionary(processed_docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
#Filters words that appears in less than 15 articles
#or in more than 0.5 o the articles
#Keeps first 100 000 most frequent tokens
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)
# Out:
# 0 abandon
# 1 abil
# 2 absenc
# 3 acknowledg
# 4 act
# 5 activ
# 6 actual
# 7 adventur
# 8 age
# 9 agenc
# 10 agent

# %%
#Create dictionary for each article
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus[0]
# Out:
# [(0, 1),
#  (1, 1),
#  (2, 1),
#  (3, 1),
#  (4, 1),
#  (5, 3),
#  (6, 1),
#  (7, 1),
#  (8, 1),
#  (9, 1),
#  (10, 8),
#  (11, 1),
#  (12, 1),
#  (13, 2),
#  (14, 1),
#  (15, 1),
#  (16, 2),
#  (17, 1),
#  (18, 1),
#  (19, 1),
#  (20, 1),
#  (21, 1),
#  (22, 14),
#  (23, 1),
#  (24, 1),
#  (25, 1),
#  (26, 3),
#  (27, 2),
#  (28, 2),
#  (29, 2),
#  (30, 1),
#  (31, 1),
#  (32, 1),
#  (33, 1),
#  (34, 2),
#  (35, 1),
#  (36, 1),
#  (37, 1),
#  (38, 1),
#  (39, 1),
#  (40, 2),
#  (41, 2),
#  (42, 1),
#  (43, 1),
#  (44, 1),
#  (45, 3),
#  (46, 1),
#  (47, 2),
#  (48, 1),
#  (49, 1),
#  (50, 1),
#  (51, 1),
#  (52, 2),
#  (53, 1),
#  (54, 1),
#  (55, 1),
#  (56, 2),
#  (57, 1),
#  (58, 1),
#  (59, 1),
#  (60, 6),
#  (61, 2),
#  (62, 5),
#  (63, 1),
#  (64, 1),
#  (65, 1),
#  (66, 3),
#  (67, 1),
#  (68, 1),
#  (69, 2),
#  (70, 1),
#  (71, 1),
#  (72, 1),
#  (73, 1),
#  (74, 1),
#  (75, 6),
#  (76, 1),
#  (77, 2),
#  (78, 1),
#  (79, 1),
#  (80, 1),
#  (81, 3),
#  (82, 3),
#  (83, 1),
#  (84, 2),
#  (85, 32),
#  (86, 1),
#  (87, 1),
#  (88, 2),
#  (89, 1),
#  (90, 7),
#  (91, 1),
#  (92, 3),
#  (93, 2),
#  (94, 1),
#  (95, 2),
#  (96, 2),
#  (97, 3),
#  (98, 1),
#  (99, 1),
#  (100, 1),
#  (101, 1),
#  (102, 1),
#  (103, 1),
#  (104, 1),
#  (105, 1),
#  (106, 3),
#  (107, 1),
#  (108, 1),
#  (109, 1),
#  (110, 1),
#  (111, 2),
#  (112, 5),
#  (113, 1),
#  (114, 1),
#  (115, 1),
#  (116, 2),
#  (117, 1),
#  (118, 1),
#  (119, 1),
#  (120, 1),
#  (121, 1),
#  (122, 1),
#  (123, 1),
#  (124, 8),
#  (125, 2),
#  (126, 2),
#  (127, 1),
#  (128, 2),
#  (129, 1),
#  (130, 5),
#  (131, 5),
#  (132, 1),
#  (133, 3),
#  (134, 1),
#  (135, 1),
#  (136, 1),
#  (137, 1),
#  (138, 1),
#  (139, 1),
#  (140, 1),
#  (141, 1),
#  (142, 1),
#  (143, 2),
#  (144, 1),
#  (145, 1),
#  (146, 4),
#  (147, 2),
#  (148, 5),
#  (149, 5),
#  (150, 1),
#  (151, 1),
#  (152, 1),
#  (153, 3),
#  (154, 1),
#  (155, 1),
#  (156, 1),
#  (157, 1),
#  (158, 1),
#  (159, 1),
#  (160, 1),
#  (161, 1),
#  (162, 2),
#  (163, 1),
#  (164, 2),
#  (165, 1),
#  (166, 1),
#  (167, 1),
#  (168, 1),
#  (169, 1),
#  (170, 1),
#  (171, 1),
#  (172, 1),
#  (173, 1),
#  (174, 1),
#  (175, 6),
#  (176, 2),
#  (177, 2),
#  (178, 1),
#  (179, 1),
#  (180, 1),
#  (181, 2),
#  (182, 2),
#  (183, 1),
#  (184, 1),
#  (185, 1),
#  (186, 4),
#  (187, 1),
#  (188, 1),
#  (189, 1),
#  (190, 1),
#  (191, 1),
#  (192, 1),
#  (193, 1),
#  (194, 1),
#  (195, 2),
#  (196, 1),
#  (197, 1),
#  (198, 1),
#  (199, 1),
#  (200, 1),
#  (201, 1),
#  (202, 1),
#  (203, 5),
#  (204, 1),
#  (205, 4),
#  (206, 1),
#  (207, 3),
#  (208, 1),
#  (209, 1),
#  (210, 2),
#  (211, 3),
#  (212, 3),
#  (213, 4),
#  (214, 4),
#  (215, 1),
#  (216, 9),
#  (217, 1),
#  (218, 1),
#  (219, 1),
#  (220, 1),
#  (221, 1),
#  (222, 4),
#  (223, 2),
#  (224, 1),
#  (225, 2),
#  (226, 1),
#  (227, 1),
#  (228, 2),
#  (229, 1),
#  (230, 1),
#  (231, 1),
#  (232, 1),
#  (233, 1),
#  (234, 1),
#  (235, 1),
#  (236, 2),
#  (237, 1),
#  (238, 2),
#  (239, 1),
#  (240, 1),
#  (241, 7),
#  (242, 1),
#  (243, 6),
#  (244, 4),
#  (245, 2),
#  (246, 2),
#  (247, 1),
#  (248, 1),
#  (249, 1),
#  (250, 1),
#  (251, 1),
#  (252, 1),
#  (253, 1),
#  (254, 1),
#  (255, 1),
#  (256, 2),
#  (257, 1),
#  (258, 1),
#  (259, 2),
#  (260, 2),
#  (261, 1),
#  (262, 3),
#  (263, 1),
#  (264, 1),
#  (265, 4),
#  (266, 1),
#  (267, 1),
#  (268, 1),
#  (269, 1),
#  (270, 1),
#  (271, 1),
#  (272, 21),
#  (273, 3),
#  (274, 1),
#  (275, 1),
#  (276, 1),
#  (277, 1),
#  (278, 1),
#  (279, 1),
#  (280, 2),
#  (281, 1),
#  (282, 4),
#  (283, 2),
#  (284, 1),
#  (285, 1),
#  (286, 1),
#  (287, 1),
#  (288, 1),
#  (289, 2),
#  (290, 1),
#  (291, 1),
#  (292, 1),
#  (293, 3),
#  (294, 5),
#  (295, 1),
#  (296, 1),
#  (297, 1),
#  (298, 2),
#  (299, 1),
#  (300, 1),
#  (301, 3),
#  (302, 2),
#  (303, 1),
#  (304, 1),
#  (305, 1),
#  (306, 1),
#  (307, 1),
#  (308, 2),
#  (309, 1),
#  (310, 1),
#  (311, 1),
#  (312, 1),
#  (313, 2),
#  (314, 1),
#  (315, 1),
#  (316, 3),
#  (317, 2),
#  (318, 1),
#  (319, 5),
#  (320, 1),
#  (321, 2),
#  (322, 1),
#  (323, 1),
#  (324, 1),
#  (325, 8),
#  (326, 3),
#  (327, 3),
#  (328, 1),
#  (329, 1),
#  (330, 1),
#  (331, 12),
#  (332, 1),
#  (333, 1),
#  (334, 1),
#  (335, 1),
#  (336, 1),
#  (337, 6),
#  (338, 1),
#  (339, 2),
#  (340, 2),
#  (341, 1),
#  (342, 1),
#  (343, 1),
#  (344, 1),
#  (345, 2),
#  (346, 5),
#  (347, 1),
#  (348, 1),
#  (349, 1),
#  (350, 2),
#  (351, 1),
#  (352, 1),
#  (353, 1),
#  (354, 3),
#  (355, 1),
#  (356, 1),
#  (357, 1),
#  (358, 1),
#  (359, 1),
#  (360, 2),
#  (361, 1),
#  (362, 1),
#  (363, 3),
#  (364, 3),
#  (365, 18),
#  (366, 1),
#  (367, 1),
#  (368, 3),
#  (369, 1),
#  (370, 1),
#  (371, 2),
#  (372, 1),
#  (373, 1),
#  (374, 1),
#  (375, 1),
#  (376, 1),
#  (377, 1),
#  (378, 1),
#  (379, 1),
#  (380, 4),
#  (381, 1),
#  (382, 1),
#  (383, 1),
#  (384, 1),
#  (385, 3),
#  (386, 1),
#  (387, 1),
#  (388, 2),
#  (389, 1),
#  (390, 2),
#  (391, 1),
#  (392, 1),
#  (393, 1),
#  (394, 3),
#  (395, 2),
#  (396, 1),
#  (397, 4),
#  (398, 1),
#  (399, 1),
#  (400, 1),
#  (401, 1),
#  (402, 2),
#  (403, 2),
#  (404, 4),
#  (405, 2),
#  (406, 17),
#  (407, 1),
#  (408, 2),
#  (409, 4),
#  (410, 3),
#  (411, 1),
#  (412, 1),
#  (413, 1),
#  (414, 1),
#  (415, 1),
#  (416, 2),
#  (417, 1),
#  (418, 7),
#  (419, 1),
#  (420, 1),
#  (421, 2),
#  (422, 1),
#  (423, 1),
#  (424, 1),
#  (425, 1),
#  (426, 2),
#  (427, 1),
#  (428, 2),
#  (429, 1),
#  (430, 1),
#  (431, 5),
#  (432, 1),
#  (433, 5),
#  (434, 5),
#  (435, 1),
#  (436, 1),
#  (437, 2),
#  (438, 1),
#  (439, 1),
#  (440, 1),
#  (441, 1),
#  (442, 1),
#  (443, 2),
#  (444, 2),
#  (445, 10),
#  (446, 1),
#  (447, 1)]

# %%
#Bag of words for first article?
bow_doc_1 = bow_corpus[0]
for i in range(len(bow_doc_1)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_1[i][0], 
                                               dictionary[bow_doc_1[i][0]], 
bow_doc_1[i][0]))
# Out:
# Word 0 ("abandon") appears 0 time.
# Word 1 ("abil") appears 1 time.
# Word 2 ("absenc") appears 2 time.
# Word 3 ("acknowledg") appears 3 time.
# Word 4 ("act") appears 4 time.
# Word 5 ("activ") appears 5 time.
# Word 6 ("actual") appears 6 time.
# Word 7 ("adventur") appears 7 time.
# Word 8 ("age") appears 8 time.
# Word 9 ("agenc") appears 9 time.
# Word 10 ("agent") appears 10 time.
# Word 11 ("ahead") appears 11 time.
# Word 12 ("alarm") appears 12 time.
# Word 13 ("alien") appears 13 time.
# Word 14 ("ambiti") appears 14 time.
# Word 15 ("angri") appears 15 time.
# Word 16 ("anymor") appears 16 time.
# Word 17 ("apart") appears 17 time.
# Word 18 ("appear") appears 18 time.
# Word 19 ("appreci") appears 19 time.
# Word 20 ("aspect") appears 20 time.
# Word 21 ("attent") appears 21 time.
# Word 22 ("audienc") appears 22 time.
# Word 23 ("avatar") appears 23 time.
# Word 24 ("away") appears 24 time.
# Word 25 ("awkward") appears 25 time.
# Word 26 ("baffl") appears 26 time.
# Word 27 ("basi") appears 27 time.
# Word 28 ("beat") appears 28 time.
# Word 29 ("begin") appears 29 time.
# Word 30 ("behav") appears 30 time.
# Word 31 ("believ") appears 31 time.
# Word 32 ("biggest") appears 32 time.
# Word 33 ("bizarr") appears 33 time.
# Word 34 ("black") appears 34 time.
# Word 35 ("blame") appears 35 time.
# Word 36 ("blank") appears 36 time.
# Word 37 ("bleed") appears 37 time.
# Word 38 ("blind") appears 38 time.
# Word 39 ("board") appears 39 time.
# Word 40 ("bodi") appears 40 time.
# Word 41 ("bounc") appears 41 time.
# Word 42 ("box") appears 42 time.
# Word 43 ("brain") appears 43 time.
# Word 44 ("brash") appears 44 time.
# Word 45 ("break") appears 45 time.
# Word 46 ("breakfast") appears 46 time.
# Word 47 ("bring") appears 47 time.
# Word 48 ("budget") appears 48 time.
# Word 49 ("build") appears 49 time.
# Word 50 ("cabl") appears 50 time.
# Word 51 ("canada") appears 51 time.
# Word 52 ("cancel") appears 52 time.
# Word 53 ("capabl") appears 53 time.
# Word 54 ("capac") appears 54 time.
# Word 55 ("carri") appears 55 time.
# Word 56 ("case") appears 56 time.
# Word 57 ("cast") appears 57 time.
# Word 58 ("catch") appears 58 time.
# Word 59 ("caus") appears 59 time.
# Word 60 ("chang") appears 60 time.
# Word 61 ("chao") appears 61 time.
# Word 62 ("charact") appears 62 time.
# Word 63 ("charm") appears 63 time.
# Word 64 ("cheer") appears 64 time.
# Word 65 ("cherri") appears 65 time.
# Word 66 ("claim") appears 66 time.
# Word 67 ("clear") appears 67 time.
# Word 68 ("clip") appears 68 time.
# Word 69 ("clue") appears 69 time.
# Word 70 ("coffe") appears 70 time.
# Word 71 ("collid") appears 71 time.
# Word 72 ("color") appears 72 time.
# Word 73 ("communiti") appears 73 time.
# Word 74 ("compel") appears 74 time.
# Word 75 ("confid") appears 75 time.
# Word 76 ("confront") appears 76 time.
# Word 77 ("confus") appears 77 time.
# Word 78 ("consid") appears 78 time.
# Word 79 ("consist") appears 79 time.
# Word 80 ("construct") appears 80 time.
# Word 81 ("consum") appears 81 time.
# Word 82 ("control") appears 82 time.
# Word 83 ("convers") appears 83 time.
# Word 84 ("convinc") appears 84 time.
# Word 85 ("cooper") appears 85 time.
# Word 86 ("couldn") appears 86 time.
# Word 87 ("cours") appears 87 time.
# Word 88 ("creativ") appears 88 time.
# Word 89 ("curious") appears 89 time.
# Word 90 ("dale") appears 90 time.
# Word 91 ("dark") appears 91 time.
# Word 92 ("david") appears 92 time.
# Word 93 ("day") appears 93 time.
# Word 94 ("decad") appears 94 time.
# Word 95 ("defin") appears 95 time.
# Word 96 ("detail") appears 96 time.
# Word 97 ("develop") appears 97 time.
# Word 98 ("distract") appears 98 time.
# Word 99 ("divid") appears 99 time.
# Word 100 ("domain") appears 100 time.
# Word 101 ("domest") appears 101 time.
# Word 102 ("dougla") appears 102 time.
# Word 103 ("downright") appears 103 time.
# Word 104 ("downward") appears 104 time.
# Word 105 ("dozen") appears 105 time.
# Word 106 ("drama") appears 106 time.
# Word 107 ("draw") appears 107 time.
# Word 108 ("dream") appears 108 time.
# Word 109 ("drop") appears 109 time.
# Word 110 ("eager") appears 110 time.
# Word 111 ("earl") appears 111 time.
# Word 112 ("earli") appears 112 time.
# Word 113 ("eat") appears 113 time.
# Word 114 ("eject") appears 114 time.
# Word 115 ("electr") appears 115 time.
# Word 116 ("emerg") appears 116 time.
# Word 117 ("emul") appears 117 time.
# Word 118 ("end") appears 118 time.
# Word 119 ("endless") appears 119 time.
# Word 120 ("endur") appears 120 time.
# Word 121 ("enthusiasm") appears 121 time.
# Word 122 ("entir") appears 122 time.
# Word 123 ("entranc") appears 123 time.
# Word 124 ("episod") appears 124 time.
# Word 125 ("errat") appears 125 time.
# Word 126 ("event") appears 126 time.
# Word 127 ("eventu") appears 127 time.
# Word 128 ("exact") appears 128 time.
# Word 129 ("exhaust") appears 129 time.
# Word 130 ("expect") appears 130 time.
# Word 131 ("experi") appears 131 time.
# Word 132 ("explor") appears 132 time.
# Word 133 ("face") appears 133 time.
# Word 134 ("fact") appears 134 time.
# Word 135 ("fail") appears 135 time.
# Word 136 ("fals") appears 136 time.
# Word 137 ("famili") appears 137 time.
# Word 138 ("fan") appears 138 time.
# Word 139 ("favorit") appears 139 time.
# Word 140 ("feedback") appears 140 time.
# Word 141 ("feel") appears 141 time.
# Word 142 ("felt") appears 142 time.
# Word 143 ("final") appears 143 time.
# Word 144 ("float") appears 144 time.
# Word 145 ("flock") appears 145 time.
# Word 146 ("follow") appears 146 time.
# Word 147 ("food") appears 147 time.
# Word 148 ("forc") appears 148 time.
# Word 149 ("form") appears 149 time.
# Word 150 ("format") appears 150 time.
# Word 151 ("free") appears 151 time.
# Word 152 ("freedom") appears 152 time.
# Word 153 ("fresh") appears 153 time.
# Word 154 ("frighten") appears 154 time.
# Word 155 ("frost") appears 155 time.
# Word 156 ("frustrat") appears 156 time.
# Word 157 ("fulfil") appears 157 time.
# Word 158 ("function") appears 158 time.
# Word 159 ("funni") appears 159 time.
# Word 160 ("get") appears 160 time.
# Word 161 ("giant") appears 161 time.
# Word 162 ("give") appears 162 time.
# Word 163 ("glass") appears 163 time.
# Word 164 ("glow") appears 164 time.
# Word 165 ("good") appears 165 time.
# Word 166 ("grind") appears 166 time.
# Word 167 ("groundbreak") appears 167 time.
# Word 168 ("grow") appears 168 time.
# Word 169 ("happen") appears 169 time.
# Word 170 ("have") appears 170 time.
# Word 171 ("haze") appears 171 time.
# Word 172 ("head") appears 172 time.
# Word 173 ("hear") appears 173 time.
# Word 174 ("heavili") appears 174 time.
# Word 175 ("help") appears 175 time.
# Word 176 ("helpless") appears 176 time.
# Word 177 ("hero") appears 177 time.
# Word 178 ("highest") appears 178 time.
# Word 179 ("hold") appears 179 time.
# Word 180 ("hostag") appears 180 time.
# Word 181 ("hour") appears 181 time.
# Word 182 ("human") appears 182 time.
# Word 183 ("humor") appears 183 time.
# Word 184 ("idea") appears 184 time.
# Word 185 ("ident") appears 185 time.
# Word 186 ("imag") appears 186 time.
# Word 187 ("impair") appears 187 time.
# Word 188 ("inconsist") appears 188 time.
# Word 189 ("infinit") appears 189 time.
# Word 190 ("inform") appears 190 time.
# Word 191 ("instead") appears 191 time.
# Word 192 ("intend") appears 192 time.
# Word 193 ("interact") appears 193 time.
# Word 194 ("intern") appears 194 time.
# Word 195 ("interpret") appears 195 time.
# Word 196 ("jean") appears 196 time.
# Word 197 ("job") appears 197 time.
# Word 198 ("kill") appears 198 time.
# Word 199 ("kind") appears 199 time.
# Word 200 ("knowledg") appears 200 time.
# Word 201 ("kyle") appears 201 time.
# Word 202 ("launch") appears 202 time.
# Word 203 ("laura") appears 203 time.
# Word 204 ("learn") appears 204 time.
# Word 205 ("leav") appears 205 time.
# Word 206 ("let") appears 206 time.
# Word 207 ("life") appears 207 time.
# Word 208 ("lifestyl") appears 208 time.
# Word 209 ("listen") appears 209 time.
# Word 210 ("littl") appears 210 time.
# Word 211 ("live") appears 211 time.
# Word 212 ("lodg") appears 212 time.
# Word 213 ("long") appears 213 time.
# Word 214 ("lose") appears 214 time.
# Word 215 ("love") appears 215 time.
# Word 216 ("lynch") appears 216 time.
# Word 217 ("machin") appears 217 time.
# Word 218 ("magic") appears 218 time.
# Word 219 ("mapl") appears 219 time.
# Word 220 ("mark") appears 220 time.
# Word 221 ("mastermind") appears 221 time.
# Word 222 ("matur") appears 222 time.
# Word 223 ("mean") appears 223 time.
# Word 224 ("media") appears 224 time.
# Word 225 ("mediat") appears 225 time.
# Word 226 ("member") appears 226 time.
# Word 227 ("mental") appears 227 time.
# Word 228 ("merci") appears 228 time.
# Word 229 ("method") appears 229 time.
# Word 230 ("mileston") appears 230 time.
# Word 231 ("miss") appears 231 time.
# Word 232 ("mode") appears 232 time.
# Word 233 ("moment") appears 233 time.
# Word 234 ("monster") appears 234 time.
# Word 235 ("motion") appears 235 time.
# Word 236 ("motiv") appears 236 time.
# Word 237 ("mountain") appears 237 time.
# Word 238 ("move") appears 238 time.
# Word 239 ("movi") appears 239 time.
# Word 240 ("muddl") appears 240 time.
# Word 241 ("murder") appears 241 time.
# Word 242 ("mutat") appears 242 time.
# Word 243 ("mysteri") appears 243 time.
# Word 244 ("narrat") appears 244 time.
# Word 245 ("natur") appears 245 time.
# Word 246 ("navig") appears 246 time.
# Word 247 ("need") appears 247 time.
# Word 248 ("nervous") appears 248 time.
# Word 249 ("network") appears 249 time.
# Word 250 ("nightmar") appears 250 time.
# Word 251 ("object") appears 251 time.
# Word 252 ("obscur") appears 252 time.
# Word 253 ("obsess") appears 253 time.
# Word 254 ("oldest") appears 254 time.
# Word 255 ("ongo") appears 255 time.
# Word 256 ("open") appears 256 time.
# Word 257 ("opera") appears 257 time.
# Word 258 ("optimist") appears 258 time.
# Word 259 ("order") appears 259 time.
# Word 260 ("origin") appears 260 time.
# Word 261 ("outnumb") appears 261 time.
# Word 262 ("outsid") appears 262 time.
# Word 263 ("outsiz") appears 263 time.
# Word 264 ("pain") appears 264 time.
# Word 265 ("palmer") appears 265 time.
# Word 266 ("parallel") appears 266 time.
# Word 267 ("parti") appears 267 time.
# Word 268 ("particip") appears 268 time.
# Word 269 ("partner") appears 269 time.
# Word 270 ("passiv") appears 270 time.
# Word 271 ("past") appears 271 time.
# Word 272 ("peak") appears 272 time.
# Word 273 ("peopl") appears 273 time.
# Word 274 ("person") appears 274 time.
# Word 275 ("pick") appears 275 time.
# Word 276 ("piec") appears 276 time.
# Word 277 ("pilot") appears 277 time.
# Word 278 ("place") appears 278 time.
# Word 279 ("play") appears 279 time.
# Word 280 ("pleasur") appears 280 time.
# Word 281 ("plummet") appears 281 time.
# Word 282 ("point") appears 282 time.
# Word 283 ("popular") appears 283 time.
# Word 284 ("posit") appears 284 time.
# Word 285 ("possibl") appears 285 time.
# Word 286 ("premier") appears 286 time.
# Word 287 ("problem") appears 287 time.
# Word 288 ("procedur") appears 288 time.
# Word 289 ("process") appears 289 time.
# Word 290 ("program") appears 290 time.
# Word 291 ("progress") appears 291 time.
# Word 292 ("prolifer") appears 292 time.
# Word 293 ("promis") appears 293 time.
# Word 294 ("protagonist") appears 294 time.
# Word 295 ("pull") appears 295 time.
# Word 296 ("puls") appears 296 time.
# Word 297 ("punctur") appears 297 time.
# Word 298 ("quirki") appears 298 time.
# Word 299 ("random") appears 299 time.
# Word 300 ("rapid") appears 300 time.
# Word 301 ("rat") appears 301 time.
# Word 302 ("reason") appears 302 time.
# Word 303 ("reassur") appears 303 time.
# Word 304 ("recaptur") appears 304 time.
# Word 305 ("recogn") appears 305 time.
# Word 306 ("record") appears 306 time.
# Word 307 ("regain") appears 307 time.
# Word 308 ("reject") appears 308 time.
# Word 309 ("relat") appears 309 time.
# Word 310 ("remain") appears 310 time.
# Word 311 ("rememb") appears 311 time.
# Word 312 ("remind") appears 312 time.
# Word 313 ("repeat") appears 313 time.
# Word 314 ("repres") appears 314 time.
# Word 315 ("rescu") appears 315 time.
# Word 316 ("return") appears 316 time.
# Word 317 ("reveal") appears 317 time.
# Word 318 ("revel") appears 318 time.
# Word 319 ("reviv") appears 319 time.
# Word 320 ("ride") appears 320 time.
# Word 321 ("right") appears 321 time.
# Word 322 ("roll") appears 322 time.
# Word 323 ("scout") appears 323 time.
# Word 324 ("screen") appears 324 time.
# Word 325 ("season") appears 325 time.
# Word 326 ("second") appears 326 time.
# Word 327 ("see") appears 327 time.
# Word 328 ("send") appears 328 time.
# Word 329 ("sens") appears 329 time.
# Word 330 ("sensat") appears 330 time.
# Word 331 ("seri") appears 331 time.
# Word 332 ("serial") appears 332 time.
# Word 333 ("shape") appears 333 time.
# Word 334 ("sharpli") appears 334 time.
# Word 335 ("sheer") appears 335 time.
# Word 336 ("shoot") appears 336 time.
# Word 337 ("showtim") appears 337 time.
# Word 338 ("silli") appears 338 time.
# Word 339 ("size") appears 339 time.
# Word 340 ("slot") appears 340 time.
# Word 341 ("slow") appears 341 time.
# Word 342 ("slowli") appears 342 time.
# Word 343 ("smell") appears 343 time.
# Word 344 ("soap") appears 344 time.
# Word 345 ("solut") appears 345 time.
# Word 346 ("solv") appears 346 time.
# Word 347 ("sophist") appears 347 time.
# Word 348 ("sort") appears 348 time.
# Word 349 ("soul") appears 349 time.
# Word 350 ("space") appears 350 time.
# Word 351 ("special") appears 351 time.
# Word 352 ("specif") appears 352 time.
# Word 353 ("spend") appears 353 time.
# Word 354 ("spirit") appears 354 time.
# Word 355 ("spoiler") appears 355 time.
# Word 356 ("stack") appears 356 time.
# Word 357 ("stagger") appears 357 time.
# Word 358 ("stake") appears 358 time.
# Word 359 ("stand") appears 359 time.
# Word 360 ("start") appears 360 time.
# Word 361 ("steadili") appears 361 time.
# Word 362 ("steal") appears 362 time.
# Word 363 ("stick") appears 363 time.
# Word 364 ("stop") appears 364 time.
# Word 365 ("stori") appears 365 time.
# Word 366 ("storytel") appears 366 time.
# Word 367 ("strain") appears 367 time.
# Word 368 ("strang") appears 368 time.
# Word 369 ("stranger") appears 369 time.
# Word 370 ("stride") appears 370 time.
# Word 371 ("stumbl") appears 371 time.
# Word 372 ("sudden") appears 372 time.
# Word 373 ("suffer") appears 373 time.
# Word 374 ("suggest") appears 374 time.
# Word 375 ("supernatur") appears 375 time.
# Word 376 ("surfac") appears 376 time.
# Word 377 ("surpris") appears 377 time.
# Word 378 ("surround") appears 378 time.
# Word 379 ("tackl") appears 379 time.
# Word 380 ("take") appears 380 time.
# Word 381 ("talk") appears 381 time.
# Word 382 ("tape") appears 382 time.
# Word 383 ("tast") appears 383 time.
# Word 384 ("televis") appears 384 time.
# Word 385 ("tell") appears 385 time.
# Word 386 ("textur") appears 386 time.
# Word 387 ("thing") appears 387 time.
# Word 388 ("think") appears 388 time.
# Word 389 ("thorough") appears 389 time.
# Word 390 ("threaten") appears 390 time.
# Word 391 ("throw") appears 391 time.
# Word 392 ("tini") appears 392 time.
# Word 393 ("today") appears 393 time.
# Word 394 ("tone") appears 394 time.
# Word 395 ("tool") appears 395 time.
# Word 396 ("top") appears 396 time.
# Word 397 ("town") appears 397 time.
# Word 398 ("track") appears 398 time.
# Word 399 ("tragic") appears 399 time.
# Word 400 ("transform") appears 400 time.
# Word 401 ("translat") appears 401 time.
# Word 402 ("trap") appears 402 time.
# Word 403 ("trend") appears 403 time.
# Word 404 ("tri") appears 404 time.
# Word 405 ("trial") appears 405 time.
# Word 406 ("twin") appears 406 time.
# Word 407 ("uncertain") appears 407 time.
# Word 408 ("unclear") appears 408 time.
# Word 409 ("understand") appears 409 time.
# Word 410 ("unexpect") appears 410 time.
# Word 411 ("unfold") appears 411 time.
# Word 412 ("unlik") appears 412 time.
# Word 413 ("unseen") appears 413 time.
# Word 414 ("unusu") appears 414 time.
# Word 415 ("vast") appears 415 time.
# Word 416 ("victim") appears 416 time.
# Word 417 ("view") appears 417 time.
# Word 418 ("viewer") appears 418 time.
# Word 419 ("viewership") appears 419 time.
# Word 420 ("virtual") appears 420 time.
# Word 421 ("visibl") appears 421 time.
# Word 422 ("vision") appears 422 time.
# Word 423 ("visit") appears 423 time.
# Word 424 ("vivid") appears 424 time.
# Word 425 ("vocabulari") appears 425 time.
# Word 426 ("voic") appears 426 time.
# Word 427 ("wacki") appears 427 time.
# Word 428 ("wait") appears 428 time.
# Word 429 ("walk") appears 429 time.
# Word 430 ("wander") appears 430 time.
# Word 431 ("want") appears 431 time.
# Word 432 ("wasn") appears 432 time.
# Word 433 ("watch") appears 433 time.
# Word 434 ("way") appears 434 time.
# Word 435 ("weari") appears 435 time.
# Word 436 ("weird") appears 436 time.
# Word 437 ("weren") appears 437 time.
# Word 438 ("will") appears 438 time.
# Word 439 ("wind") appears 439 time.
# Word 440 ("withdraw") appears 440 time.
# Word 441 ("woman") appears 441 time.
# Word 442 ("wonder") appears 442 time.
# Word 443 ("word") appears 443 time.
# Word 444 ("work") appears 444 time.
# Word 445 ("world") appears 445 time.
# Word 446 ("wrong") appears 446 time.
# Word 447 ("young") appears 447 time.

# %%
#Creates tf-idf model 
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.016998787472690183),
#  (1, 0.011938920302744968),
#  (2, 0.017899655963463254),
#  (3, 0.013068614393794567),
#  (4, 0.012922320600284023),
#  (5, 0.025828599631591044),
#  (6, 0.009072356706132927),
#  (7, 0.018254609799108045),
#  (8, 0.0164640476635656),
#  (9, 0.010214029208323082),
#  (10, 0.09784641978660945),
#  (11, 0.011447790366833122),
#  (12, 0.018003387492813567),
#  (13, 0.036006774985627134),
#  (14, 0.017171685550249685),
#  (15, 0.0180738209759145),
#  (16, 0.03593711645937826),
#  (17, 0.012827233967582615),
#  (18, 0.006905123507381933),
#  (19, 0.016970572712410995),
#  (20, 0.018038473800795093),
#  (21, 0.011700924008309526),
#  (22, 0.17860005250544556),
#  (23, 0.024065284998395456),
#  (24, 0.00709863401074585),
#  (25, 0.019143562067200606),
#  (26, 0.08545337969324686),
#  (27, 0.03371871782472538),
#  (28, 0.021132702679937384),
#  (29, 0.012120792849488698),
#  (30, 0.02276056471433239),
#  (31, 0.007723399366035063),
#  (32, 0.010844981195764502),
#  (33, 0.02040869312244433),
#  (34, 0.021147342169059096),
#  (35, 0.014831997720755087),
#  (36, 0.021440655365741936),
#  (37, 0.021298729209794552),
#  (38, 0.019861633604033643),
#  (39, 0.010625227301742696),
#  (40, 0.02128012185471798),
#  (41, 0.024420174178242268),
#  (42, 0.018291607442271495),
#  (43, 0.01702717068029708),
#  (44, 0.028177632593214447),
#  (45, 0.014993498074804271),
#  (46, 0.022666419595279593),
#  (47, 0.012808442744884605),
#  (48, 0.014226409058556653),
#  (49, 0.006533972942599159),
#  (50, 0.01683195726213579),
#  (51, 0.016777623263275913),
#  (52, 0.03488685309360533),
#  (53, 0.014940876673685993),
#  (54, 0.01896907741423739),
#  (55, 0.01061782780896005),
#  (56, 0.015342793907153061),
#  (57, 0.01469059924926944),
#  (58, 0.010303151141830239),
#  (59, 0.00963298541998721),
#  (60, 0.02444148771616551),
#  (61, 0.038376405037373225),
#  (62, 0.054497913180433344),
#  (63, 0.019610031343840612),
#  (64, 0.016886919413623008),
#  (65, 0.026452317037995613),
#  (66, 0.030459881207764168),
#  (67, 0.007623894411969099),
#  (68, 0.01783173804905064),
#  (69, 0.04363038660042135),
#  (70, 0.018926438804186128),
#  (71, 0.022137633666899508),
#  (72, 0.012722486625439762),
#  (73, 0.009341584594049017),
#  (74, 0.01714242900774805),
#  (75, 0.07388747170427118),
#  (76, 0.01609909823856538),
#  (77, 0.03272791222155111),
#  (78, 0.008732260034527067),
#  (79, 0.013717616177982974),
#  (80, 0.014010273060243699),
#  (81, 0.0344760466568643),
#  (82, 0.025147275136729468),
#  (83, 0.011492015552288102),
#  (84, 0.03025614605429041),
#  (85, 0.4981711273918149),
#  (86, 0.01159986531489464),
#  (87, 0.008424189646405117),
#  (88, 0.029992531450581023),
#  (89, 0.02058588778696878),
#  (90, 0.19152438700763508),
#  (91, 0.014403403795700211),
#  (92, 0.026837557187369725),
#  (93, 0.010290378642877322),
#  (94, 0.009207812397450183),
#  (95, 0.031476838645981435),
#  (96, 0.018751248330769143),
#  (97, 0.020848046078510735),
#  (98, 0.018328895265991886),
#  (99, 0.016777623263275913),
#  (100, 0.024456259157197558),
#  (101, 0.016314689626859627),
#  (102, 0.023477602847584975),
#  (103, 0.027360626715376438),
#  (104, 0.024322329930222562),
#  (105, 0.011199093414592779),
#  (106, 0.044712917791919535),
#  (107, 0.009711768932207774),
#  (108, 0.014290010985769062),
#  (109, 0.010093324393639011),
#  (110, 0.0150335535490109),
#  (111, 0.05332729682843774),
#  (112, 0.03493547020322102),
#  (113, 0.018759608593631735),
#  (114, 0.022856611883081742),
#  (115, 0.016290246523385253),
#  (116, 0.021736610136634364),
#  (117, 0.025517122238148095),
#  (118, 0.008971931304590723),
#  (119, 0.02089672874573333),
#  (120, 0.01814531364876095),
#  (121, 0.021440655365741936),
#  (122, 0.010180191534138131),
#  (123, 0.020072964980256895),
#  (124, 0.12179607892998964),
#  (125, 0.04947199416544584),
#  (126, 0.018660584031858638),
#  (127, 0.011456602553143206),
#  (128, 0.022895580733666245),
#  (129, 0.02052608607830194),
#  (130, 0.03340133368054852),
#  (131, 0.040218263772401584),
#  (132, 0.013550296628418),
#  (133, 0.019857883175537137),
#  (134, 0.009748575617881065),
#  (135, 0.010472206220915894),
#  (136, 0.017633618834604813),
#  (137, 0.006680266736109704),
#  (138, 0.011018741083016046),
#  (139, 0.0112919018714724),
#  (140, 0.019417917401544582),
#  (141, 0.007194825134110681),
#  (142, 0.010891743931667603),
#  (143, 0.012002465235047062),
#  (144, 0.018328895265991886),
#  (145, 0.02295463954473752),
#  (146, 0.017063781579161098),
#  (147, 0.025491130362424407),
#  (148, 0.040477820845484465),
#  (149, 0.053878441882946375),
#  (150, 0.01654052394780181),
#  (151, 0.005326322587534235),
#  (152, 0.01605248832451281),
#  (153, 0.04645440988108379),
#  (154, 0.02370403483942532),
#  (155, 0.02848445989774895),
#  (156, 0.014673216512708148),
#  (157, 0.02083291338283644),
#  (158, 0.014621446420528844),
#  (159, 0.019278760935831737),
#  (160, 0.006334639486063843),
#  (161, 0.012158690122017809),
#  (162, 0.009905409875845924),
#  (163, 0.01614616964441855),
#  (164, 0.04590927908947504),
#  (165, 0.005377613933337376),
#  (166, 0.011465431103782665),
#  (167, 0.024322329930222562),
#  (168, 0.00826379268873106),
#  (169, 0.0072564038568050954),
#  (170, 0.008777228901991015),
#  (171, 0.027889412643756523),
#  (172, 0.007102162154249608),
#  (173, 0.008447551723652873),
#  (174, 0.01546426687665075),
#  (175, 0.0298783809249217),
#  (176, 0.054721253430752875),
#  (177, 0.03507514333171092),
#  (178, 0.014743132083814108),
#  (179, 0.004874747669820695),
#  (180, 0.024594070926775537),
#  (181, 0.015366694245601161),
#  (182, 0.020703681955802123),
#  (183, 0.019709080200463934),
#  (184, 0.009196832777897726),
#  (185, 0.014708045775832583),
#  (186, 0.04900643406382622),
#  (187, 0.026055906431313374),
#  (188, 0.022137633666899508),
#  (189, 0.02666364841421887),
#  (190, 0.008035055693994528),
#  (191, 0.009035110615154985),
#  (192, 0.014163646785298167),
#  (193, 0.014403403795700211),
#  (194, 0.008108631075590714),
#  (195, 0.036218865852696236),
#  (196, 0.019278760935831737),
#  (197, 0.014163646785298167),
#  (198, 0.0057823597599825785),
#  (199, 0.007941500072707405),
#  (200, 0.015782035896378922),
#  (201, 0.017633618834604813),
#  (202, 0.00949088249283554),
#  (203, 0.10091130565301995),
#  (204, 0.009669184882848233),
#  (205, 0.016474366182288355),
#  (206, 0.014242229948874476),
#  (207, 0.023002260689009835),
#  (208, 0.02122932398951868),
#  (209, 0.014604314246482267),
#  (210, 0.009262885591716303),
#  (211, 0.01894098886589152),
#  (212, 0.06978440054781607),
#  (213, 0.02013698350419598),
#  (214, 0.027811070926279054),
#  (215, 0.009296574334504515),
#  (216, 0.19633673970189608),
#  (217, 0.014725556562307104),
#  (218, 0.015782035896378922),
#  (219, 0.027617671647203544),
#  (220, 0.005890536740049257),
#  (221, 0.026452317037995613),
#  (222, 0.08117651675868467),
#  (223, 0.012478986766164131),
#  (224, 0.0095851442801457),
#  (225, 0.0513800406314152),
#  (226, 0.005149868626100988),
#  (227, 0.007866300686983173),
#  (228, 0.04764285559056585),
#  (229, 0.015546950232937541),
#  (230, 0.02122932398951868),
#  (231, 0.009126076748363406),
#  (232, 0.0180738209759145),
#  (233, 0.008777228901991015),
#  (234, 0.020707796342171528),
#  (235, 0.015484803293694598),
#  (236, 0.0309285337533015),
#  (237, 0.015983419218850752),
#  (238, 0.013589346246674756),
#  (239, 0.011308972529501287),
#  (240, 0.027617671647203544),
#  (241, 0.10394980352245978),
#  (242, 0.026884812623633136),
#  (243, 0.09788813776115776),
#  (244, 0.06810868272118832),
#  (245, 0.021162004232575433),
#  (246, 0.03507514333171092),
#  (247, 0.005022836767734228),
#  (248, 0.019055519307484208),
#  (249, 0.011059133621263902),
#  (250, 0.020961412371467647),
#  (251, 0.014322133899555577),
#  (252, 0.021369162692895478),
#  (253, 0.019709080200463934),
#  (254, 0.021026988213241574),
#  (255, 0.0156737356972564),
#  (256, 0.010503208012721348),
#  (257, 0.02276056471433239),
#  (258, 0.017899655963463254),
#  (259, 0.01769607409018666),
#  (260, 0.015584544547285552),
#  (261, 0.026884812623633136),
#  (262, 0.027475807725758035),
#  (263, 0.026055906431313374),
#  (264, 0.014290010985769062),
#  (265, 0.08757510585514794),
#  (266, 0.022307443616287344),
#  (267, 0.010573671084529548),
#  (268, 0.012839016311043549),
#  (269, 0.011968297367299345),
#  (270, 0.0256900203157076),
#  (271, 0.008304523597913659),
#  (272, 0.3864915582444182),
#  (273, 0.009909815847800983),
#  (274, 0.006154881747250234),
#  (275, 0.009567327245601763),
#  (276, 0.0117195313633861),
#  (277, 0.017731646496260592),
#  (278, 0.005906977701056136),
#  (279, 0.004330522520229936),
#  (280, 0.04590927908947504),
#  (281, 0.023941793038297764),
#  (282, 0.020534044679086594),
#  (283, 0.013354076190948316),
#  (284, 0.008551731001202257),
#  (285, 0.007954149764834946),
#  (286, 0.016998787472690183),
#  (287, 0.008345606482828808),
#  (288, 0.016998787472690183),
#  (289, 0.018958460203646055),
#  (290, 0.006117435779052916),
#  (291, 0.010200465224362918),
#  (292, 0.023821427795282926),
#  (293, 0.03354723626450772),
#  (294, 0.13027953215656687),
#  (295, 0.009969153362956945),
#  (296, 0.024065284998395456),
#  (297, 0.02848445989774895),
#  (298, 0.04673661339447576),
#  (299, 0.019759389380546586),
#  (300, 0.015760177590503223),
#  (301, 0.03697546560817961),
#  (302, 0.017902113491367198),
#  (303, 0.021369162692895478),
#  (304, 0.027617671647203544),
#  (305, 0.014502797795388996),
#  (306, 0.0069254840230973695),
#  (307, 0.021513239571862183),
#  (308, 0.03238742354427364),
#  (309, 0.007311408401950021),
#  (310, 0.007234578999104925),
#  (311, 0.013043917334862048),
#  (312, 0.014996265725290512),
#  (313, 0.02528516534951732),
#  (314, 0.008919915762158323),
#  (315, 0.017899655963463254),
#  (316, 0.02254460047830071),
#  (317, 0.024399526295413292),
#  (318, 0.019278760935831737),
#  (319, 0.09359399994910417),
#  (320, 0.015244034218753741),
#  (321, 0.009038856598181695),
#  (322, 0.011710218582439326),
#  (323, 0.019233266108720632),
#  (324, 0.011832731310164218),
#  (325, 0.052422411005890575),
#  (326, 0.014591143622456788),
#  (327, 0.019992436243845734),
#  (328, 0.008485171489905645),
#  (329, 0.010768051148998094),
#  (330, 0.021026988213241574),
#  (331, 0.10233423159368771),
#  (332, 0.0253502920275937),
#  (333, 0.013564017195381708),
#  (334, 0.021026988213241574),
#  (335, 0.023261466849272022),
#  (336, 0.00516628255711412),
#  (337, 0.14020984018342728),
#  (338, 0.023054731097527568),
#  (339, 0.025217490001147418),
#  (340, 0.042738325385790955),
#  (341, 0.01297058673213879),
#  (342, 0.01651489491994933),
#  (343, 0.02295463954473752),
#  (344, 0.026055906431313374),
#  (345, 0.028580021971538125),
#  (346, 0.07957669601821783),
#  (347, 0.019561270166100757),
#  (348, 0.012497661135018105),
#  (349, 0.019913592297746367),
#  (350, 0.02216706981145811),
#  (351, 0.00987336422960363),
#  (352, 0.0114039727925717),
#  (353, 0.008091216502444445),
#  (354, 0.05041413792685515),
#  (355, 0.026452317037995613),
#  (356, 0.021661819575156206),
#  (357, 0.023941793038297764),
#  (358, 0.015322943468489036),
#  (359, 0.008254788570219265),
#  (360, 0.008872217497225247),
#  (361, 0.022666419595279593),
#  (362, 0.007691330622834706),
#  (363, 0.037658635899715916),
#  (364, 0.017315028660933443),
#  (365, 0.13328137654280714),
#  (366, 0.021093481229350966),
#  (367, 0.01685935891236269),
#  (368, 0.04985475174229615),
#  (369, 0.020127298979116772),
#  (370, 0.021661819575156206),
#  (371, 0.040254597958233544),
#  (372, 0.014638640555556713),
#  (373, 0.01189035835698642),
#  (374, 0.010282435757625191),
#  (375, 0.02666364841421887),
#  (376, 0.015244034218753741),
#  (377, 0.010768051148998094),
#  (378, 0.013920569018723678),
#  (379, 0.015937924391739643),
#  (380, 0.015016684994221275),
#  (381, 0.006606557148719407),
#  (382, 0.020351066075622135),
#  (383, 0.018926438804186128),
#  (384, 0.01198798341262484),
#  (385, 0.014479176836015418),
#  (386, 0.024322329930222562),
#  (387, 0.005424502083920176),
#  (388, 0.00892879091031166),
#  (389, 0.02089672874573333),
#  (390, 0.026337411893169228),
#  (391, 0.00963298541998721),
#  (392, 0.015588837492034548),
#  (393, 0.007866300686983173),
#  (394, 0.05261271499756639),
#  (395, 0.027841138037447356),
#  (396, 0.018800770523083103),
#  (397, 0.05084395689624306),
#  (398, 0.010573671084529548),
#  (399, 0.02089672874573333),
#  (400, 0.016339259051843035),
#  (401, 0.01685935891236269),
#  (402, 0.03513874454748707),
#  (403, 0.029881753347371986),
#  (404, 0.024264278652281875),
#  (405, 0.029346433025416296),
#  (406, 0.31961309889241274),
#  (407, 0.020351066075622135),
#  (408, 0.02945111312461421),
#  (409, 0.0383405771205828),
#  (410, 0.05729801064523689),
#  (411, 0.02029412918967117),
#  (412, 0.012107842865634077),
#  (413, 0.026884812623633136),
#  (414, 0.014338277117623827),
#  (415, 0.015244034218753741),
#  (416, 0.026186880839353742),
#  (417, 0.009543674594062563),
#  (418, 0.11820843589536105),
#  (419, 0.02848445989774895),
#  (420, 0.015128073027145205),
#  (421, 0.0362906272975219),
#  (422, 0.014519567382981444),
#  (423, 0.0112919018714724),
#  (424, 0.02018226113060399),
#  (425, 0.02848445989774895),
#  (426, 0.014289410749273963),
#  (427, 0.02848445989774895),
#  (428, 0.021030852549027576),
#  (429, 0.009131482289767956),
#  (430, 0.02295463954473752),
#  (431, 0.02218054374306312),
#  (432, 0.009040413653243174),
#  (433, 0.02857989078592715),
#  (434, 0.053015316420977704),
#  (435, 0.026452317037995613),
#  (436, 0.017865575723235588),
#  (437, 0.02945111312461421),
#  (438, 0.014148084829821678),
#  (439, 0.01119074543500602),
#  (440, 0.017899655963463254),
#  (441, 0.009841858659346),
#  (442, 0.01093897120566236),
#  (443, 0.020987534267696895),
#  (444, 0.007456127394413335),
#  (445, 0.059900463225905545),
#  (446, 0.012464835873522236),
#  (447, 0.008992897923592338)]

# %%
#Training LDA model
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=30, id2word=dictionary, passes=2, workers=2)

# %%
# For each topic, explore the words that occur in that topic and its relative weight
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.007*"angel" + 0.007*"california" + 0.006*"citi" + 0.005*"presid" + 0.004*"break" + 0.004*"polic" + 0.004*"trump" + 0.004*"chang" + 0.004*"report" + 0.003*"getti"
# Topic: 1
# Words: 0.007*"citi" + 0.006*"angel" + 0.004*"polic" + 0.004*"game" + 0.004*"california" + 0.004*"peopl" + 0.004*"break" + 0.004*"getti" + 0.003*"train" + 0.003*"uber"
# Topic: 2
# Words: 0.004*"peopl" + 0.003*"human" + 0.003*"angel" + 0.003*"start" + 0.003*"work" + 0.003*"report" + 0.003*"area" + 0.003*"california" + 0.003*"offici" + 0.003*"home"
# Topic: 3
# Words: 0.011*"student" + 0.010*"presid" + 0.009*"school" + 0.009*"california" + 0.008*"trump" + 0.007*"break" + 0.006*"angel" + 0.006*"getti" + 0.005*"member" + 0.005*"program"
# Topic: 4
# Words: 0.015*"water" + 0.008*"round" + 0.007*"land" + 0.007*"punch" + 0.006*"look" + 0.005*"fight" + 0.005*"california" + 0.005*"get" + 0.004*"takedown" + 0.004*"right"
# Topic: 5
# Words: 0.009*"season" + 0.009*"play" + 0.006*"game" + 0.006*"angel" + 0.005*"team" + 0.004*"point" + 0.004*"home" + 0.004*"hamilton" + 0.003*"coach" + 0.003*"state"
# Topic: 6
# Words: 0.005*"fight" + 0.005*"peopl" + 0.004*"food" + 0.004*"water" + 0.004*"want" + 0.004*"court" + 0.003*"amprsquo" + 0.003*"mayweath" + 0.003*"california" + 0.003*"state"
# Topic: 7
# Words: 0.007*"play" + 0.007*"film" + 0.006*"chang" + 0.005*"star" + 0.005*"favorit" + 0.005*"music" + 0.004*"angel" + 0.004*"offic" + 0.004*"artist" + 0.004*"charact"
# Topic: 8
# Words: 0.011*"play" + 0.008*"game" + 0.007*"round" + 0.007*"hole" + 0.005*"player" + 0.005*"shoot" + 0.005*"team" + 0.005*"dodger" + 0.005*"duck" + 0.005*"final"
# Topic: 9
# Words: 0.005*"california" + 0.005*"presid" + 0.005*"work" + 0.004*"peopl" + 0.004*"chang" + 0.004*"state" + 0.003*"offici" + 0.003*"trump" + 0.003*"offic" + 0.003*"citi"
# Topic: 10
# Words: 0.006*"work" + 0.005*"film" + 0.004*"includ" + 0.004*"home" + 0.004*"citi" + 0.004*"play" + 0.004*"live" + 0.003*"take" + 0.003*"million" + 0.003*"look"
# Topic: 11
# Words: 0.007*"organ" + 0.006*"team" + 0.005*"game" + 0.005*"angel" + 0.005*"ram" + 0.005*"peopl" + 0.005*"leav" + 0.005*"klein" + 0.004*"charger" + 0.004*"discuss"
# Topic: 12
# Words: 0.009*"angel" + 0.004*"california" + 0.004*"citi" + 0.004*"counti" + 0.003*"offici" + 0.003*"million" + 0.003*"report" + 0.003*"game" + 0.003*"includ" + 0.003*"peopl"
# Topic: 13
# Words: 0.006*"citi" + 0.006*"polic" + 0.005*"angel" + 0.004*"peopl" + 0.004*"report" + 0.004*"star" + 0.004*"work" + 0.003*"offic" + 0.003*"includ" + 0.003*"member"
# Topic: 14
# Words: 0.015*"game" + 0.012*"dodger" + 0.011*"point" + 0.011*"inning" + 0.008*"season" + 0.008*"second" + 0.008*"leav" + 0.007*"start" + 0.007*"play" + 0.006*"right"
# Topic: 15
# Words: 0.006*"game" + 0.005*"peopl" + 0.004*"work" + 0.004*"right" + 0.004*"team" + 0.004*"angel" + 0.003*"need" + 0.003*"play" + 0.003*"cancer" + 0.003*"week"
# Topic: 16
# Words: 0.009*"compani" + 0.006*"state" + 0.004*"presid" + 0.004*"peopl" + 0.004*"month" + 0.004*"work" + 0.003*"citi" + 0.003*"plan" + 0.003*"nation" + 0.003*"million"
# Topic: 17
# Words: 0.008*"presid" + 0.008*"trump" + 0.006*"hous" + 0.005*"peopl" + 0.005*"report" + 0.004*"state" + 0.004*"investig" + 0.004*"campaign" + 0.003*"includ" + 0.003*"california"
# Topic: 18
# Words: 0.017*"california" + 0.010*"presid" + 0.009*"trump" + 0.009*"ktla" + 0.008*"credit" + 0.008*"getti" + 0.008*"break" + 0.008*"southern" + 0.008*"angel" + 0.007*"wave"
# Topic: 19
# Words: 0.021*"game" + 0.013*"team" + 0.010*"play" + 0.009*"season" + 0.007*"point" + 0.007*"player" + 0.006*"coach" + 0.005*"second" + 0.005*"score" + 0.005*"final"
# Topic: 20
# Words: 0.006*"state" + 0.004*"work" + 0.004*"peopl" + 0.004*"million" + 0.004*"compani" + 0.004*"california" + 0.003*"build" + 0.003*"want" + 0.003*"offici" + 0.003*"world"
# Topic: 21
# Words: 0.006*"state" + 0.005*"citi" + 0.005*"vote" + 0.005*"presid" + 0.004*"democrat" + 0.004*"peopl" + 0.004*"includ" + 0.004*"nation" + 0.004*"hous" + 0.004*"offici"
# Topic: 22
# Words: 0.010*"polic" + 0.007*"health" + 0.006*"presid" + 0.006*"california" + 0.005*"credit" + 0.005*"trump" + 0.005*"break" + 0.004*"heat" + 0.004*"getti" + 0.004*"shoot"
# Topic: 23
# Words: 0.008*"duck" + 0.005*"game" + 0.005*"peopl" + 0.005*"shoot" + 0.005*"blackhawk" + 0.005*"goal" + 0.004*"state" + 0.004*"period" + 0.004*"chicago" + 0.004*"polic"
# Topic: 24
# Words: 0.012*"polic" + 0.011*"offic" + 0.010*"shoot" + 0.005*"kill" + 0.005*"deputi" + 0.004*"angel" + 0.004*"depart" + 0.004*"sheriff" + 0.004*"report" + 0.004*"counti"
# Topic: 25
# Words: 0.010*"polic" + 0.010*"offic" + 0.007*"citi" + 0.006*"angel" + 0.006*"california" + 0.005*"member" + 0.005*"report" + 0.005*"peopl" + 0.004*"trump" + 0.004*"homeless"
# Topic: 26
# Words: 0.006*"googl" + 0.006*"compani" + 0.005*"peopl" + 0.005*"angel" + 0.004*"california" + 0.004*"polic" + 0.004*"work" + 0.004*"counti" + 0.004*"author" + 0.003*"servic"
# Topic: 27
# Words: 0.009*"chang" + 0.008*"favorit" + 0.008*"star" + 0.007*"video" + 0.006*"justin" + 0.005*"play" + 0.005*"game" + 0.005*"direct" + 0.005*"charact" + 0.005*"actor"
# Topic: 28
# Words: 0.006*"second" + 0.005*"peopl" + 0.005*"open" + 0.004*"shoot" + 0.004*"play" + 0.004*"want" + 0.004*"point" + 0.004*"leav" + 0.003*"think" + 0.003*"work"
# Topic: 29
# Words: 0.009*"amprsquo" + 0.007*"team" + 0.005*"compani" + 0.005*"want" + 0.005*"work" + 0.005*"peopl" + 0.004*"think" + 0.004*"organ" + 0.003*"ampmdash" + 0.003*"thing"

# %%
#LDA using TF-IDF
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=30, id2word=dictionary, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.002*"game" + 0.002*"appl" + 0.002*"compani" + 0.001*"team" + 0.001*"dodger" + 0.001*"polic" + 0.001*"california" + 0.001*"state" + 0.001*"chef" + 0.001*"amprsquo"
# Topic: 1 Word: 0.002*"point" + 0.002*"game" + 0.002*"amprsquo" + 0.002*"polic" + 0.002*"score" + 0.002*"california" + 0.001*"trump" + 0.001*"clipper" + 0.001*"rain" + 0.001*"divis"
# Topic: 2 Word: 0.003*"california" + 0.002*"immigr" + 0.002*"dodger" + 0.002*"trump" + 0.002*"getti" + 0.002*"ktla" + 0.002*"presid" + 0.002*"credit" + 0.002*"polic" + 0.002*"southern"
# Topic: 3 Word: 0.003*"california" + 0.003*"getti" + 0.003*"ktla" + 0.003*"polic" + 0.003*"credit" + 0.003*"presid" + 0.002*"wave" + 0.002*"heat" + 0.002*"lapd" + 0.002*"trump"
# Topic: 4 Word: 0.002*"laker" + 0.002*"favorit" + 0.002*"robot" + 0.002*"game" + 0.002*"justin" + 0.002*"season" + 0.002*"golf" + 0.002*"appl" + 0.002*"point" + 0.001*"inning"
# Topic: 5 Word: 0.003*"alford" + 0.003*"ucla" + 0.003*"bruin" + 0.003*"laker" + 0.003*"game" + 0.002*"score" + 0.002*"season" + 0.001*"point" + 0.001*"team" + 0.001*"california"
# Topic: 6 Word: 0.004*"trump" + 0.003*"presid" + 0.002*"california" + 0.002*"ktla" + 0.002*"getti" + 0.002*"hous" + 0.002*"king" + 0.002*"game" + 0.002*"credit" + 0.002*"polic"
# Topic: 7 Word: 0.005*"trump" + 0.005*"california" + 0.005*"getti" + 0.004*"ktla" + 0.004*"presid" + 0.004*"credit" + 0.003*"heat" + 0.003*"polic" + 0.003*"wave" + 0.003*"lapd"
# Topic: 8 Word: 0.002*"california" + 0.002*"game" + 0.002*"polic" + 0.001*"googl" + 0.001*"team" + 0.001*"mayweath" + 0.001*"prosecutor" + 0.001*"shoot" + 0.001*"investig" + 0.001*"offic"
# Topic: 9 Word: 0.005*"california" + 0.004*"getti" + 0.004*"ktla" + 0.004*"trump" + 0.004*"credit" + 0.004*"presid" + 0.003*"polic" + 0.003*"heat" + 0.003*"wave" + 0.003*"southern"
# Topic: 10 Word: 0.006*"clipper" + 0.005*"game" + 0.005*"ram" + 0.004*"season" + 0.004*"charger" + 0.004*"team" + 0.003*"klein" + 0.003*"point" + 0.003*"minicamp" + 0.003*"offseason"
# Topic: 11 Word: 0.005*"inning" + 0.004*"game" + 0.003*"dodger" + 0.003*"pitch" + 0.003*"season" + 0.003*"hit" + 0.002*"leagu" + 0.002*"defeat" + 0.002*"team" + 0.002*"pitcher"
# Topic: 12 Word: 0.003*"trump" + 0.003*"california" + 0.002*"presid" + 0.002*"getti" + 0.002*"ktla" + 0.002*"credit" + 0.002*"polic" + 0.002*"southern" + 0.002*"heat" + 0.002*"wave"
# Topic: 13 Word: 0.003*"california" + 0.003*"presid" + 0.003*"trump" + 0.003*"getti" + 0.003*"ktla" + 0.002*"credit" + 0.002*"polic" + 0.002*"heat" + 0.002*"wave" + 0.002*"southern"
# Topic: 14 Word: 0.004*"california" + 0.003*"getti" + 0.003*"ktla" + 0.003*"credit" + 0.003*"wave" + 0.002*"polic" + 0.002*"heat" + 0.002*"southern" + 0.002*"presid" + 0.002*"trump"
# Topic: 15 Word: 0.003*"game" + 0.002*"team" + 0.002*"dodger" + 0.002*"laker" + 0.002*"season" + 0.002*"compani" + 0.001*"play" + 0.001*"california" + 0.001*"film" + 0.001*"state"
# Topic: 16 Word: 0.003*"devic" + 0.003*"trump" + 0.002*"amprsquo" + 0.002*"california" + 0.002*"window" + 0.002*"polic" + 0.002*"microsoft" + 0.002*"presid" + 0.002*"phone" + 0.002*"nokia"
# Topic: 17 Word: 0.002*"california" + 0.002*"getti" + 0.002*"ktla" + 0.002*"credit" + 0.002*"trump" + 0.002*"polic" + 0.002*"presid" + 0.002*"station" + 0.002*"southern" + 0.002*"wave"
# Topic: 18 Word: 0.003*"dodger" + 0.003*"california" + 0.002*"game" + 0.002*"polic" + 0.002*"water" + 0.002*"trump" + 0.002*"earthquak" + 0.002*"getti" + 0.002*"ktla" + 0.002*"drought"
# Topic: 19 Word: 0.005*"favorit" + 0.004*"justin" + 0.004*"actor" + 0.003*"zeitchik" + 0.003*"neubert" + 0.003*"abraham" + 0.003*"conni" + 0.003*"golf" + 0.003*"charact" + 0.003*"jason"
# Topic: 20 Word: 0.002*"game" + 0.002*"duck" + 0.002*"team" + 0.002*"charger" + 0.002*"thiri" + 0.002*"offseason" + 0.002*"organ" + 0.002*"minicamp" + 0.002*"lindsey" + 0.002*"gari"
# Topic: 21 Word: 0.002*"clinton" + 0.002*"compani" + 0.002*"spotifi" + 0.002*"trump" + 0.002*"game" + 0.002*"amprsquo" + 0.002*"planet" + 0.001*"polic" + 0.001*"xbox" + 0.001*"favorit"
# Topic: 22 Word: 0.002*"compani" + 0.002*"game" + 0.002*"patent" + 0.001*"team" + 0.001*"facebook" + 0.001*"score" + 0.001*"film" + 0.001*"microsoft" + 0.001*"play" + 0.001*"favorit"
# Topic: 23 Word: 0.002*"california" + 0.002*"school" + 0.002*"trump" + 0.002*"presid" + 0.002*"student" + 0.002*"polic" + 0.002*"state" + 0.002*"ktla" + 0.002*"getti" + 0.002*"credit"
# Topic: 24 Word: 0.002*"trump" + 0.002*"california" + 0.002*"presid" + 0.002*"getti" + 0.002*"ktla" + 0.001*"credit" + 0.001*"wave" + 0.001*"hole" + 0.001*"program" + 0.001*"heat"
# Topic: 25 Word: 0.002*"trump" + 0.001*"polic" + 0.001*"presid" + 0.001*"saudi" + 0.001*"compani" + 0.001*"state" + 0.001*"game" + 0.001*"california" + 0.001*"comcast" + 0.001*"islam"
# Topic: 26 Word: 0.002*"snapchat" + 0.002*"dodger" + 0.002*"laker" + 0.002*"game" + 0.001*"california" + 0.001*"polic" + 0.001*"music" + 0.001*"award" + 0.001*"raider" + 0.001*"play"
# Topic: 27 Word: 0.002*"game" + 0.002*"laker" + 0.002*"season" + 0.002*"point" + 0.002*"spieth" + 0.001*"star" + 0.001*"amprsquo" + 0.001*"play" + 0.001*"california" + 0.001*"scott"
# Topic: 28 Word: 0.002*"twain" + 0.002*"star" + 0.001*"knbc" + 0.001*"kcbs" + 0.001*"film" + 0.001*"biden" + 0.001*"favorit" + 0.001*"kttv" + 0.001*"kabc" + 0.001*"koce"
# Topic: 29 Word: 0.002*"amprsquo" + 0.002*"game" + 0.002*"california" + 0.001*"ampmdash" + 0.001*"dodger" + 0.001*"season" + 0.001*"polic" + 0.001*"trump" + 0.001*"attack" + 0.001*"disney"

# %%
#Getting the category of the first article

# print(processed_docs[0]) #This is the article
for index, score in sorted(lda_model[bow_corpus[0]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# The topic with the highest score/probability is the topic most likely associated
# with it
# Out:
# Score: 0.45125436782836914
# Topic: 0.011*"play" + 0.008*"game" + 0.007*"round" + 0.007*"hole" + 0.005*"player" + 0.005*"shoot" + 0.005*"team" + 0.005*"dodger" + 0.005*"duck" + 0.005*"final"
#
# Score: 0.14750249683856964
# Topic: 0.006*"work" + 0.005*"film" + 0.004*"includ" + 0.004*"home" + 0.004*"citi" + 0.004*"play" + 0.004*"live" + 0.003*"take" + 0.003*"million" + 0.003*"look"
#
# Score: 0.1388128399848938
# Topic: 0.006*"state" + 0.004*"work" + 0.004*"peopl" + 0.004*"million" + 0.004*"compani" + 0.004*"california" + 0.003*"build" + 0.003*"want" + 0.003*"offici" + 0.003*"world"
#
# Score: 0.12325345724821091
# Topic: 0.006*"second" + 0.005*"peopl" + 0.005*"open" + 0.004*"shoot" + 0.004*"play" + 0.004*"want" + 0.004*"point" + 0.004*"leav" + 0.003*"think" + 0.003*"work"
#
# Score: 0.07749078422784805
# Topic: 0.009*"amprsquo" + 0.007*"team" + 0.005*"compani" + 0.005*"want" + 0.005*"work" + 0.005*"peopl" + 0.004*"think" + 0.004*"organ" + 0.003*"ampmdash" + 0.003*"thing"
#
# Score: 0.036733228713274
# Topic: 0.006*"googl" + 0.006*"compani" + 0.005*"peopl" + 0.005*"angel" + 0.004*"california" + 0.004*"polic" + 0.004*"work" + 0.004*"counti" + 0.004*"author" + 0.003*"servic"
#
# Score: 0.024057773873209953
# Topic: 0.009*"chang" + 0.008*"favorit" + 0.008*"star" + 0.007*"video" + 0.006*"justin" + 0.005*"play" + 0.005*"game" + 0.005*"direct" + 0.005*"charact" + 0.005*"actor"

# %%
#Getting the topic of the first article with the LDA TF-IDF model
for index, score in sorted(lda_model_tfidf[bow_corpus[0]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.8168314099311829
# Topic: 0.003*"game" + 0.002*"team" + 0.002*"dodger" + 0.002*"laker" + 0.002*"season" + 0.002*"compani" + 0.001*"play" + 0.001*"california" + 0.001*"film" + 0.001*"state"
#
# Score: 0.07523132860660553
# Topic: 0.002*"point" + 0.002*"game" + 0.002*"amprsquo" + 0.002*"polic" + 0.002*"score" + 0.002*"california" + 0.001*"trump" + 0.001*"clipper" + 0.001*"rain" + 0.001*"divis"
#
# Score: 0.04065573588013649
# Topic: 0.006*"clipper" + 0.005*"game" + 0.005*"ram" + 0.004*"season" + 0.004*"charger" + 0.004*"team" + 0.003*"klein" + 0.003*"point" + 0.003*"minicamp" + 0.003*"offseason"
#
# Score: 0.022257493808865547
# Topic: 0.005*"trump" + 0.005*"california" + 0.005*"getti" + 0.004*"ktla" + 0.004*"presid" + 0.004*"credit" + 0.003*"heat" + 0.003*"polic" + 0.003*"wave" + 0.003*"lapd"
#
# Score: 0.02047869749367237
# Topic: 0.003*"devic" + 0.003*"trump" + 0.002*"amprsquo" + 0.002*"california" + 0.002*"window" + 0.002*"polic" + 0.002*"microsoft" + 0.002*"presid" + 0.002*"phone" + 0.002*"nokia"
#
# Score: 0.010527832433581352
# Topic: 0.002*"clinton" + 0.002*"compani" + 0.002*"spotifi" + 0.002*"trump" + 0.002*"game" + 0.002*"amprsquo" + 0.002*"planet" + 0.001*"polic" + 0.001*"xbox" + 0.001*"favorit"

# %%
# Topic modeling is a type of statistical modeling for discovering the abstract “topics” that occur in a collection of documents. Latent Dirichlet Allocation (LDA) is an example of topic model and is used to classify text in a document to a particular topic. 
# It builds a topic per document model and words per topic model, modeled as Dirichlet distributions.
import numpy as np
import pandas as pd
import nltk
import gensim

# %%
data = pd.read_csv('news-data.csv', error_bad_lines=False);
data_text = data[['content']]
data_text['index'] = data_text.index
documents = data_text
# documents = data_text[:1000]
# Out:
# c:\users\owner\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print("Number of articles:", len(documents))
print(documents[:5])
# Out:
# Number of articles: 1000
#                                              content  index
# 0        And never more so than in Showtime’s new...      0
# 1        AlphaGo’s victory isn’t a defeat for hum...      1
# 2        Super Deluxe built a weird internet empi...      2
# 3        Steven Yang quit his job at Google in th...      3
# 4        Ahead of Black Panther’s 2018 theatrical...      4

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Functions that perform lemmatization and stemming as part of preprocessing
def lemmatize_stemming(text):
    return SnowballStemmer("english").stem(WordNetLemmatizer().lemmatize(text, pos='v'))
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
#Selects the first article to compare before and after preprocessing
doc_sample = documents[documents['index'] == 0].values[0][0]
print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words[:20])
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample)[:20])
# Out:
# original document:
# ['', '', '', '', '', '', 'And', 'never', 'more', 'so', 'than', 'in', 'Showtime’s', 'new', 'series', 'revival', 'Some', 'spoilers', 'ahead', 'through']
#
#
#  tokenized and lemmatized document:
# ['showtim', 'seri', 'reviv', 'spoiler', 'ahead', 'episod', 'season', 'twin', 'peak', 'showtim', 'bring', 'david', 'lynch', 'groundbreak', 'seri', 'twin', 'peak', 'fulfil', 'propheci', 'process']

# %%
#All the preprocessed articles
processed_docs = documents['content'].map(preprocess)
processed_docs[:10]
# Out:
# 0    [showtim, seri, reviv, spoiler, ahead, episod,...
# 1    [alphago, victori, defeat, human, opportun, lo...
# 2    [super, delux, build, weird, internet, empir, ...
# 3    [steven, yang, quit, googl, summer, build, pro...
# 4    [ahead, black, panther, theatric, releas, marv...
# 5    [facebook, instant, articl, promis, transform,...
# 6    [weapon, weapon, year, artist, technolog, enth...
# 7    [insid, busi, imagin, futur, dubai, world, loo...
# 8    [legal, threat, disgruntl, client, insid, uber...
# 9    [genius, quiet, lay, bunch, engin, surviv, med...
# Name: content, dtype: object

# %%
#Dictionary that contains the number of times a word appears
dictionary = gensim.corpora.Dictionary(processed_docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
#Filters words that appears in less than 15 articles
#or in more than 0.5 o the articles
#Keeps first 100 000 most frequent tokens
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)
# Out:
# 0 abandon
# 1 abil
# 2 absenc
# 3 acknowledg
# 4 act
# 5 activ
# 6 actual
# 7 adventur
# 8 age
# 9 agenc
# 10 agent

# %%
#Create dictionary for each article
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus[0]
# Out:
# [(1, 3),
#  (6, 7),
#  (14, 1),
#  (27, 1),
#  (30, 2),
#  (38, 2),
#  (46, 1),
#  (68, 1),
#  (70, 2),
#  (81, 1),
#  (82, 1),
#  (88, 1),
#  (91, 2),
#  (94, 2),
#  (104, 1),
#  (111, 1),
#  (114, 2),
#  (119, 1),
#  (120, 2),
#  (121, 2),
#  (122, 1),
#  (123, 1),
#  (129, 1),
#  (134, 1),
#  (145, 1),
#  (147, 1),
#  (149, 1),
#  (152, 1),
#  (155, 3),
#  (158, 4),
#  (160, 1),
#  (165, 13),
#  (167, 3),
#  (171, 1),
#  (172, 2),
#  (180, 5),
#  (181, 8),
#  (183, 15),
#  (192, 2),
#  (194, 3),
#  (204, 1),
#  (206, 4),
#  (211, 3),
#  (216, 1),
#  (219, 7),
#  (226, 1),
#  (227, 1),
#  (228, 1),
#  (229, 2),
#  (237, 3),
#  (240, 1),
#  (241, 2),
#  (243, 2),
#  (244, 14),
#  (245, 2),
#  (246, 1),
#  (247, 4),
#  (248, 5),
#  (250, 4),
#  (252, 2),
#  (253, 1),
#  (256, 1),
#  (264, 1),
#  (272, 1),
#  (278, 2),
#  (279, 1),
#  (280, 1),
#  (282, 3),
#  (283, 2),
#  (285, 1),
#  (297, 1),
#  (300, 1),
#  (302, 1),
#  (303, 1),
#  (309, 2),
#  (323, 1),
#  (328, 1),
#  (332, 1),
#  (353, 2),
#  (373, 1),
#  (383, 2),
#  (384, 2),
#  (385, 1),
#  (386, 2),
#  (387, 3),
#  (388, 1),
#  (389, 1),
#  (390, 1),
#  (391, 1),
#  (392, 1),
#  (393, 1),
#  (394, 1),
#  (395, 3),
#  (396, 1),
#  (397, 1),
#  (398, 2),
#  (399, 1),
#  (400, 2),
#  (401, 1),
#  (402, 2),
#  (403, 5),
#  (404, 1),
#  (405, 1),
#  (406, 1),
#  (407, 1),
#  (408, 3),
#  (409, 2),
#  (410, 1),
#  (411, 1),
#  (412, 1),
#  (413, 2),
#  (414, 1),
#  (415, 1),
#  (416, 1),
#  (417, 1),
#  (418, 1),
#  (419, 1),
#  (420, 1),
#  (421, 1),
#  (422, 2),
#  (423, 1),
#  (424, 2),
#  (425, 1),
#  (426, 2),
#  (427, 7),
#  (428, 1),
#  (429, 1),
#  (430, 2),
#  (431, 1),
#  (432, 1),
#  (433, 1),
#  (434, 1),
#  (435, 1),
#  (436, 3),
#  (437, 1),
#  (438, 2),
#  (439, 4),
#  (440, 1),
#  (441, 3),
#  (442, 1),
#  (443, 1),
#  (444, 1),
#  (445, 1),
#  (446, 2),
#  (447, 2),
#  (448, 1),
#  (449, 1),
#  (450, 1),
#  (451, 1),
#  (452, 1),
#  (453, 1),
#  (454, 1),
#  (455, 1),
#  (456, 2),
#  (457, 1),
#  (458, 1),
#  (459, 1),
#  (460, 1),
#  (461, 1),
#  (462, 1),
#  (463, 1),
#  (464, 1),
#  (465, 1),
#  (466, 2),
#  (467, 5),
#  (468, 12),
#  (469, 4),
#  (470, 2),
#  (471, 2),
#  (472, 1),
#  (473, 6),
#  (474, 1),
#  (475, 1),
#  (476, 1),
#  (477, 1),
#  (478, 2),
#  (479, 1),
#  (480, 6),
#  (481, 1),
#  (482, 2),
#  (483, 2),
#  (484, 1),
#  (485, 5),
#  (486, 3),
#  (487, 1),
#  (488, 3),
#  (489, 1),
#  (490, 1),
#  (491, 1),
#  (492, 1),
#  (493, 1),
#  (494, 1),
#  (495, 4),
#  (496, 2),
#  (497, 1),
#  (498, 1),
#  (499, 1),
#  (500, 1),
#  (501, 1),
#  (502, 9),
#  (503, 1),
#  (504, 1),
#  (505, 2),
#  (506, 1),
#  (507, 1),
#  (508, 1),
#  (509, 1),
#  (510, 1),
#  (511, 1),
#  (512, 1),
#  (513, 1),
#  (514, 1),
#  (515, 1),
#  (516, 1),
#  (517, 1),
#  (518, 1),
#  (519, 1),
#  (520, 1),
#  (521, 1),
#  (522, 1),
#  (523, 1),
#  (524, 1),
#  (525, 3),
#  (526, 2),
#  (527, 1),
#  (528, 1),
#  (529, 1),
#  (530, 1),
#  (531, 1),
#  (532, 3),
#  (533, 4),
#  (534, 1),
#  (535, 2),
#  (536, 6),
#  (537, 1),
#  (538, 1),
#  (539, 2),
#  (540, 2),
#  (541, 1),
#  (542, 4),
#  (543, 1),
#  (544, 1),
#  (545, 1),
#  (546, 1),
#  (547, 1),
#  (548, 1),
#  (549, 1),
#  (550, 1),
#  (551, 2),
#  (552, 1),
#  (553, 1),
#  (554, 1),
#  (555, 2),
#  (556, 1),
#  (557, 2),
#  (558, 2),
#  (559, 2),
#  (560, 2),
#  (561, 5),
#  (562, 1),
#  (563, 1),
#  (564, 4),
#  (565, 1),
#  (566, 2),
#  (567, 1),
#  (568, 1),
#  (569, 1),
#  (570, 2),
#  (571, 2),
#  (572, 3),
#  (573, 1),
#  (574, 1),
#  (575, 1),
#  (576, 1),
#  (577, 1),
#  (578, 1),
#  (579, 1),
#  (580, 1),
#  (581, 2),
#  (582, 2),
#  (583, 1),
#  (584, 2),
#  (585, 1),
#  (586, 1),
#  (587, 4),
#  (588, 1),
#  (589, 3),
#  (590, 1),
#  (591, 1),
#  (592, 1),
#  (593, 2),
#  (594, 1),
#  (595, 2),
#  (596, 1),
#  (597, 1),
#  (598, 3),
#  (599, 1),
#  (600, 2),
#  (601, 2),
#  (602, 1),
#  (603, 1),
#  (604, 1),
#  (605, 4),
#  (606, 2),
#  (607, 1),
#  (608, 1),
#  (609, 2),
#  (610, 2),
#  (611, 2),
#  (612, 3),
#  (613, 7),
#  (614, 2),
#  (615, 2),
#  (616, 5),
#  (617, 1),
#  (618, 1),
#  (619, 1),
#  (620, 2),
#  (621, 1)]

# %%
#Bag of words for first article?
bow_doc_1 = bow_corpus[0]
for i in range(len(bow_doc_1)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_1[i][0], 
                                               dictionary[bow_doc_1[i][0]], 
bow_doc_1[i][0]))
# Out:
# Word 0 ("abandon") appears 1 time.
# Word 1 ("abil") appears 1 time.
# Word 2 ("absenc") appears 1 time.
# Word 3 ("acknowledg") appears 1 time.
# Word 4 ("act") appears 1 time.
# Word 5 ("activ") appears 3 time.
# Word 6 ("actual") appears 1 time.
# Word 7 ("adventur") appears 1 time.
# Word 8 ("age") appears 1 time.
# Word 9 ("agenc") appears 1 time.
# Word 10 ("agent") appears 8 time.
# Word 11 ("ahead") appears 1 time.
# Word 12 ("alarm") appears 1 time.
# Word 13 ("alien") appears 2 time.
# Word 14 ("ambiti") appears 1 time.
# Word 15 ("angri") appears 1 time.
# Word 16 ("anymor") appears 2 time.
# Word 17 ("apart") appears 1 time.
# Word 18 ("appear") appears 1 time.
# Word 19 ("appreci") appears 1 time.
# Word 20 ("aspect") appears 1 time.
# Word 21 ("attent") appears 1 time.
# Word 22 ("audienc") appears 14 time.
# Word 23 ("avatar") appears 1 time.
# Word 24 ("away") appears 1 time.
# Word 25 ("awkward") appears 1 time.
# Word 26 ("basi") appears 2 time.
# Word 27 ("beat") appears 2 time.
# Word 28 ("begin") appears 2 time.
# Word 29 ("behav") appears 1 time.
# Word 30 ("believ") appears 1 time.
# Word 31 ("biggest") appears 1 time.
# Word 32 ("bizarr") appears 1 time.
# Word 33 ("black") appears 2 time.
# Word 34 ("blame") appears 1 time.
# Word 35 ("blank") appears 1 time.
# Word 36 ("bleed") appears 1 time.
# Word 37 ("blind") appears 1 time.
# Word 38 ("board") appears 1 time.
# Word 39 ("bodi") appears 2 time.
# Word 40 ("bounc") appears 2 time.
# Word 41 ("box") appears 1 time.
# Word 42 ("brain") appears 1 time.
# Word 43 ("break") appears 3 time.
# Word 44 ("bring") appears 2 time.
# Word 45 ("budget") appears 1 time.
# Word 46 ("build") appears 1 time.
# Word 47 ("cabl") appears 1 time.
# Word 48 ("canada") appears 1 time.
# Word 49 ("cancel") appears 2 time.
# Word 50 ("capabl") appears 1 time.
# Word 51 ("capac") appears 1 time.
# Word 52 ("carri") appears 1 time.
# Word 53 ("case") appears 2 time.
# Word 54 ("cast") appears 1 time.
# Word 55 ("catch") appears 1 time.
# Word 56 ("caus") appears 1 time.
# Word 57 ("chang") appears 6 time.
# Word 58 ("chao") appears 2 time.
# Word 59 ("charact") appears 5 time.
# Word 60 ("charm") appears 1 time.
# Word 61 ("cheer") appears 1 time.
# Word 62 ("claim") appears 3 time.
# Word 63 ("clear") appears 1 time.
# Word 64 ("clip") appears 1 time.
# Word 65 ("clue") appears 2 time.
# Word 66 ("coffe") appears 1 time.
# Word 67 ("color") appears 1 time.
# Word 68 ("communiti") appears 1 time.
# Word 69 ("compel") appears 1 time.
# Word 70 ("confid") appears 6 time.
# Word 71 ("confront") appears 1 time.
# Word 72 ("confus") appears 2 time.
# Word 73 ("consid") appears 1 time.
# Word 74 ("consist") appears 1 time.
# Word 75 ("construct") appears 1 time.
# Word 76 ("consum") appears 3 time.
# Word 77 ("control") appears 3 time.
# Word 78 ("convers") appears 1 time.
# Word 79 ("convinc") appears 2 time.
# Word 80 ("cooper") appears 32 time.
# Word 81 ("couldn") appears 1 time.
# Word 82 ("cours") appears 1 time.
# Word 83 ("creativ") appears 2 time.
# Word 84 ("curious") appears 1 time.
# Word 85 ("dark") appears 1 time.
# Word 86 ("david") appears 3 time.
# Word 87 ("day") appears 2 time.
# Word 88 ("decad") appears 1 time.
# Word 89 ("defin") appears 2 time.
# Word 90 ("detail") appears 2 time.
# Word 91 ("develop") appears 3 time.
# Word 92 ("distract") appears 1 time.
# Word 93 ("divid") appears 1 time.
# Word 94 ("domain") appears 1 time.
# Word 95 ("domest") appears 1 time.
# Word 96 ("dozen") appears 1 time.
# Word 97 ("drama") appears 3 time.
# Word 98 ("draw") appears 1 time.
# Word 99 ("dream") appears 1 time.
# Word 100 ("drop") appears 1 time.
# Word 101 ("eager") appears 1 time.
# Word 102 ("earli") appears 5 time.
# Word 103 ("eat") appears 1 time.
# Word 104 ("electr") appears 1 time.
# Word 105 ("emerg") appears 2 time.
# Word 106 ("emul") appears 1 time.
# Word 107 ("end") appears 1 time.
# Word 108 ("endless") appears 1 time.
# Word 109 ("endur") appears 1 time.
# Word 110 ("enthusiasm") appears 1 time.
# Word 111 ("entir") appears 1 time.
# Word 112 ("entranc") appears 1 time.
# Word 113 ("episod") appears 8 time.
# Word 114 ("event") appears 2 time.
# Word 115 ("eventu") appears 1 time.
# Word 116 ("exact") appears 2 time.
# Word 117 ("exhaust") appears 1 time.
# Word 118 ("expect") appears 5 time.
# Word 119 ("experi") appears 5 time.
# Word 120 ("explor") appears 1 time.
# Word 121 ("face") appears 3 time.
# Word 122 ("fact") appears 1 time.
# Word 123 ("fail") appears 1 time.
# Word 124 ("fals") appears 1 time.
# Word 125 ("famili") appears 1 time.
# Word 126 ("fan") appears 1 time.
# Word 127 ("favorit") appears 1 time.
# Word 128 ("feedback") appears 1 time.
# Word 129 ("feel") appears 1 time.
# Word 130 ("felt") appears 1 time.
# Word 131 ("final") appears 2 time.
# Word 132 ("float") appears 1 time.
# Word 133 ("flock") appears 1 time.
# Word 134 ("follow") appears 4 time.
# Word 135 ("food") appears 2 time.
# Word 136 ("forc") appears 5 time.
# Word 137 ("form") appears 5 time.
# Word 138 ("format") appears 1 time.
# Word 139 ("free") appears 1 time.
# Word 140 ("freedom") appears 1 time.
# Word 141 ("fresh") appears 3 time.
# Word 142 ("frighten") appears 1 time.
# Word 143 ("frustrat") appears 1 time.
# Word 144 ("fulfil") appears 1 time.
# Word 145 ("function") appears 1 time.
# Word 146 ("funni") appears 1 time.
# Word 147 ("get") appears 1 time.
# Word 148 ("giant") appears 1 time.
# Word 149 ("give") appears 2 time.
# Word 150 ("glass") appears 1 time.
# Word 151 ("glow") appears 2 time.
# Word 152 ("good") appears 1 time.
# Word 153 ("grind") appears 1 time.
# Word 154 ("grow") appears 1 time.
# Word 155 ("happen") appears 1 time.
# Word 156 ("have") appears 1 time.
# Word 157 ("head") appears 1 time.
# Word 158 ("hear") appears 1 time.
# Word 159 ("heavili") appears 1 time.
# Word 160 ("help") appears 6 time.
# Word 161 ("hero") appears 2 time.
# Word 162 ("highest") appears 1 time.
# Word 163 ("hold") appears 1 time.
# Word 164 ("hour") appears 2 time.
# Word 165 ("human") appears 2 time.
# Word 166 ("humor") appears 1 time.
# Word 167 ("idea") appears 1 time.
# Word 168 ("ident") appears 1 time.
# Word 169 ("imag") appears 4 time.
# Word 170 ("infinit") appears 1 time.
# Word 171 ("inform") appears 1 time.
# Word 172 ("instead") appears 1 time.
# Word 173 ("intend") appears 1 time.
# Word 174 ("interact") appears 1 time.
# Word 175 ("intern") appears 1 time.
# Word 176 ("interpret") appears 2 time.
# Word 177 ("jean") appears 1 time.
# Word 178 ("job") appears 1 time.
# Word 179 ("kill") appears 1 time.
# Word 180 ("kind") appears 1 time.
# Word 181 ("knowledg") appears 1 time.
# Word 182 ("launch") appears 1 time.
# Word 183 ("learn") appears 1 time.
# Word 184 ("leav") appears 4 time.
# Word 185 ("let") appears 1 time.
# Word 186 ("life") appears 3 time.
# Word 187 ("lifestyl") appears 1 time.
# Word 188 ("listen") appears 1 time.
# Word 189 ("littl") appears 2 time.
# Word 190 ("live") appears 3 time.
# Word 191 ("long") appears 4 time.
# Word 192 ("lose") appears 4 time.
# Word 193 ("love") appears 1 time.
# Word 194 ("machin") appears 1 time.
# Word 195 ("magic") appears 1 time.
# Word 196 ("mark") appears 1 time.
# Word 197 ("matur") appears 4 time.
# Word 198 ("mean") appears 2 time.
# Word 199 ("media") appears 1 time.
# Word 200 ("member") appears 1 time.
# Word 201 ("mental") appears 1 time.
# Word 202 ("method") appears 1 time.
# Word 203 ("mileston") appears 1 time.
# Word 204 ("miss") appears 1 time.
# Word 205 ("mode") appears 1 time.
# Word 206 ("moment") appears 1 time.
# Word 207 ("monster") appears 1 time.
# Word 208 ("motion") appears 1 time.
# Word 209 ("motiv") appears 2 time.
# Word 210 ("mountain") appears 1 time.
# Word 211 ("move") appears 2 time.
# Word 212 ("movi") appears 1 time.
# Word 213 ("murder") appears 7 time.
# Word 214 ("mysteri") appears 6 time.
# Word 215 ("narrat") appears 4 time.
# Word 216 ("natur") appears 2 time.
# Word 217 ("navig") appears 2 time.
# Word 218 ("nervous") appears 1 time.
# Word 219 ("network") appears 1 time.
# Word 220 ("nightmar") appears 1 time.
# Word 221 ("object") appears 1 time.
# Word 222 ("obscur") appears 1 time.
# Word 223 ("obsess") appears 1 time.
# Word 224 ("oldest") appears 1 time.
# Word 225 ("ongo") appears 1 time.
# Word 226 ("open") appears 2 time.
# Word 227 ("optimist") appears 1 time.
# Word 228 ("order") appears 2 time.
# Word 229 ("origin") appears 2 time.
# Word 230 ("outsid") appears 3 time.
# Word 231 ("pain") appears 1 time.
# Word 232 ("parallel") appears 1 time.
# Word 233 ("parti") appears 1 time.
# Word 234 ("particip") appears 1 time.
# Word 235 ("partner") appears 1 time.
# Word 236 ("passiv") appears 1 time.
# Word 237 ("past") appears 1 time.
# Word 238 ("peak") appears 21 time.
# Word 239 ("person") appears 1 time.
# Word 240 ("pick") appears 1 time.
# Word 241 ("piec") appears 1 time.
# Word 242 ("pilot") appears 1 time.
# Word 243 ("place") appears 1 time.
# Word 244 ("play") appears 1 time.
# Word 245 ("point") appears 4 time.
# Word 246 ("popular") appears 2 time.
# Word 247 ("posit") appears 1 time.
# Word 248 ("possibl") appears 1 time.
# Word 249 ("premier") appears 1 time.
# Word 250 ("problem") appears 1 time.
# Word 251 ("procedur") appears 1 time.
# Word 252 ("process") appears 2 time.
# Word 253 ("program") appears 1 time.
# Word 254 ("progress") appears 1 time.
# Word 255 ("prolifer") appears 1 time.
# Word 256 ("promis") appears 3 time.
# Word 257 ("pull") appears 1 time.
# Word 258 ("puls") appears 1 time.
# Word 259 ("random") appears 1 time.
# Word 260 ("rapid") appears 1 time.
# Word 261 ("rat") appears 3 time.
# Word 262 ("reason") appears 2 time.
# Word 263 ("reassur") appears 1 time.
# Word 264 ("recogn") appears 1 time.
# Word 265 ("record") appears 1 time.
# Word 266 ("reject") appears 2 time.
# Word 267 ("relat") appears 1 time.
# Word 268 ("remain") appears 1 time.
# Word 269 ("rememb") appears 1 time.
# Word 270 ("remind") appears 1 time.
# Word 271 ("repeat") appears 2 time.
# Word 272 ("repres") appears 1 time.
# Word 273 ("return") appears 3 time.
# Word 274 ("reveal") appears 2 time.
# Word 275 ("revel") appears 1 time.
# Word 276 ("reviv") appears 5 time.
# Word 277 ("ride") appears 1 time.
# Word 278 ("right") appears 2 time.
# Word 279 ("roll") appears 1 time.
# Word 280 ("screen") appears 1 time.
# Word 281 ("season") appears 8 time.
# Word 282 ("second") appears 3 time.
# Word 283 ("see") appears 3 time.
# Word 284 ("send") appears 1 time.
# Word 285 ("sens") appears 1 time.
# Word 286 ("sensat") appears 1 time.
# Word 287 ("seri") appears 12 time.
# Word 288 ("shape") appears 1 time.
# Word 289 ("sheer") appears 1 time.
# Word 290 ("shoot") appears 1 time.
# Word 291 ("silli") appears 1 time.
# Word 292 ("size") appears 2 time.
# Word 293 ("slot") appears 2 time.
# Word 294 ("slow") appears 1 time.
# Word 295 ("slowli") appears 1 time.
# Word 296 ("smell") appears 1 time.
# Word 297 ("solut") appears 2 time.
# Word 298 ("solv") appears 5 time.
# Word 299 ("sophist") appears 1 time.
# Word 300 ("sort") appears 1 time.
# Word 301 ("soul") appears 1 time.
# Word 302 ("space") appears 2 time.
# Word 303 ("special") appears 1 time.
# Word 304 ("specif") appears 1 time.
# Word 305 ("spend") appears 1 time.
# Word 306 ("spirit") appears 3 time.
# Word 307 ("stack") appears 1 time.
# Word 308 ("stake") appears 1 time.
# Word 309 ("stand") appears 1 time.
# Word 310 ("start") appears 2 time.
# Word 311 ("steadili") appears 1 time.
# Word 312 ("steal") appears 1 time.
# Word 313 ("stick") appears 3 time.
# Word 314 ("stop") appears 3 time.
# Word 315 ("stori") appears 18 time.
# Word 316 ("storytel") appears 1 time.
# Word 317 ("strain") appears 1 time.
# Word 318 ("strang") appears 3 time.
# Word 319 ("stranger") appears 1 time.
# Word 320 ("stumbl") appears 2 time.
# Word 321 ("sudden") appears 1 time.
# Word 322 ("suffer") appears 1 time.
# Word 323 ("suggest") appears 1 time.
# Word 324 ("surfac") appears 1 time.
# Word 325 ("surpris") appears 1 time.
# Word 326 ("surround") appears 1 time.
# Word 327 ("tackl") appears 1 time.
# Word 328 ("talk") appears 1 time.
# Word 329 ("tape") appears 1 time.
# Word 330 ("tast") appears 1 time.
# Word 331 ("televis") appears 1 time.
# Word 332 ("tell") appears 3 time.
# Word 333 ("textur") appears 1 time.
# Word 334 ("thorough") appears 1 time.
# Word 335 ("threaten") appears 2 time.
# Word 336 ("throw") appears 1 time.
# Word 337 ("tini") appears 1 time.
# Word 338 ("today") appears 1 time.
# Word 339 ("tone") appears 3 time.
# Word 340 ("tool") appears 2 time.
# Word 341 ("top") appears 1 time.
# Word 342 ("town") appears 4 time.
# Word 343 ("track") appears 1 time.
# Word 344 ("transform") appears 1 time.
# Word 345 ("translat") appears 1 time.
# Word 346 ("trap") appears 2 time.
# Word 347 ("trend") appears 2 time.
# Word 348 ("tri") appears 4 time.
# Word 349 ("trial") appears 2 time.
# Word 350 ("twin") appears 17 time.
# Word 351 ("uncertain") appears 1 time.
# Word 352 ("unclear") appears 2 time.
# Word 353 ("understand") appears 4 time.
# Word 354 ("unexpect") appears 3 time.
# Word 355 ("unfold") appears 1 time.
# Word 356 ("unlik") appears 1 time.
# Word 357 ("unusu") appears 1 time.
# Word 358 ("vast") appears 1 time.
# Word 359 ("victim") appears 2 time.
# Word 360 ("view") appears 1 time.
# Word 361 ("viewer") appears 7 time.
# Word 362 ("virtual") appears 1 time.
# Word 363 ("visibl") appears 2 time.
# Word 364 ("vision") appears 1 time.
# Word 365 ("visit") appears 1 time.
# Word 366 ("voic") appears 2 time.
# Word 367 ("wait") appears 2 time.
# Word 368 ("walk") appears 1 time.
# Word 369 ("wander") appears 1 time.
# Word 370 ("wasn") appears 1 time.
# Word 371 ("watch") appears 5 time.
# Word 372 ("way") appears 5 time.
# Word 373 ("weird") appears 1 time.
# Word 374 ("weren") appears 2 time.
# Word 375 ("will") appears 1 time.
# Word 376 ("wind") appears 1 time.
# Word 377 ("withdraw") appears 1 time.
# Word 378 ("woman") appears 1 time.
# Word 379 ("wonder") appears 1 time.
# Word 380 ("word") appears 2 time.
# Word 381 ("wrong") appears 1 time.
# Word 382 ("young") appears 1 time.

# %%
#Creates tf-idf model 
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.016274810763693602),
#  (1, 0.009752602121677546),
#  (2, 0.021403971932895206),
#  (3, 0.014654855658424818),
#  (4, 0.015229934549595809),
#  (5, 0.025318550747722168),
#  (6, 0.004650247572742471),
#  (7, 0.017181388166074656),
#  (8, 0.017059615567358837),
#  (9, 0.011303701108645176),
#  (10, 0.13190344406374296),
#  (11, 0.012702182891273724),
#  (12, 0.019615668480175343),
#  (13, 0.03512727671074695),
#  (14, 0.014351194449319924),
#  (15, 0.02066415057152873),
#  (16, 0.034119231134717674),
#  (17, 0.012279850493429119),
#  (18, 0.007549267394552347),
#  (19, 0.017974228402921635),
#  (20, 0.015059446322379032),
#  (21, 0.01054792074380748),
#  (22, 0.14978166073903681),
#  (23, 0.021674290432295726),
#  (24, 0.0061257040994261314),
#  (25, 0.018899779899900764),
#  (26, 0.029626328868496594),
#  (27, 0.02900188984458125),
#  (28, 0.011320774867018935),
#  (29, 0.022258033015939926),
#  (30, 0.007549267394552347),
#  (31, 0.008568070947792553),
#  (32, 0.01981008948848401),
#  (33, 0.023311185400599756),
#  (34, 0.016709577272328753),
#  (35, 0.021403971932895206),
#  (36, 0.02066415057152873),
#  (37, 0.018265897334167742),
#  (38, 0.011982970717493565),
#  (39, 0.021397380105576687),
#  (40, 0.03962017897696802),
#  (41, 0.018417699438418197),
#  (42, 0.014205385239334309),
#  (43, 0.025091376952283556),
#  (44, 0.011921596340240087),
#  (45, 0.01587169263933813),
#  (46, 0.003907220871276383),
#  (47, 0.014976130012369596),
#  (48, 0.020220679536032175),
#  (49, 0.04132830114305746),
#  (50, 0.011747172144141733),
#  (51, 0.018417699438418197),
#  (52, 0.011177297978771678),
#  (53, 0.013230796361282918),
#  (54, 0.016940461938300688),
#  (55, 0.010853677227668423),
#  (56, 0.00953158699731138),
#  (57, 0.025597725827738078),
#  (58, 0.04280794386579041),
#  (59, 0.061912269925478186),
#  (60, 0.019615668480175343),
#  (61, 0.020899949144880567),
#  (62, 0.02822742470156803),
#  (63, 0.005832318668992676),
#  (64, 0.015229934549595809),
#  (65, 0.04132830114305746),
#  (66, 0.018899779899900764),
#  (67, 0.012229252605624298),
#  (68, 0.009817403213691409),
#  (69, 0.015587505721663461),
#  (70, 0.08887898660548978),
#  (71, 0.021958477349970397),
#  (72, 0.030118892644758064),
#  (73, 0.008646659927986477),
#  (74, 0.012540012380988714),
#  (75, 0.014894048063556676),
#  (76, 0.023999871697930882),
#  (77, 0.01952027644030638),
#  (78, 0.011476853644741212),
#  (79, 0.02416034748131166),
#  (80, 0.599500212514509),
#  (81, 0.010737032283374737),
#  (82, 0.007420911919486517),
#  (83, 0.02693112775593567),
#  (84, 0.01907026812711754),
#  (85, 0.013341054588552927),
#  (86, 0.040586651308629235),
#  (87, 0.015495108897596227),
#  (88, 0.008780170730685505),
#  (89, 0.02900188984458125),
#  (90, 0.020587122495756362),
#  (91, 0.013235333261638036),
#  (92, 0.017305897455489563),
#  (93, 0.018265897334167742),
#  (94, 0.020899949144880567),
#  (95, 0.019615668480175343),
#  (96, 0.011135796434847866),
#  (97, 0.06269984743464169),
#  (98, 0.010329191146926204),
#  (99, 0.014205385239334309),
#  (100, 0.010853677227668423),
#  (101, 0.016823816994007),
#  (102, 0.034291782376333076),
#  (103, 0.017563638355373477),
#  (104, 0.014733444638618741),
#  (105, 0.021707354455336846),
#  (106, 0.022258033015939926),
#  (107, 0.010893111061097012),
#  (108, 0.018265897334167742),
#  (109, 0.021403971932895206),
#  (110, 0.022574715218600133),
#  (111, 0.00670758716628575),
#  (112, 0.021674290432295726),
#  (113, 0.14157719326458004),
#  (114, 0.01840233069012333),
#  (115, 0.00888934530173733),
#  (116, 0.015495108897596227),
#  (117, 0.02066415057152873),
#  (118, 0.036893895836677855),
#  (119, 0.024031631752323732),
#  (120, 0.011261245497008247),
#  (121, 0.02251845296570103),
#  (122, 0.006858356475266615),
#  (123, 0.010050368531953293),
#  (124, 0.01907026812711754),
#  (125, 0.010510860871798193),
#  (126, 0.012540012380988714),
#  (127, 0.013924797172197126),
#  (128, 0.015775334902653614),
#  (129, 0.005463844061563414),
#  (130, 0.010510860871798193),
#  (131, 0.01558519768988351),
#  (132, 0.017181388166074656),
#  (133, 0.022258033015939926),
#  (134, 0.02720534442824831),
#  (135, 0.026438563979674208),
#  (136, 0.043631898618080166),
#  (137, 0.03976601134939845),
#  (138, 0.017059615567358837),
#  (139, 0.008388919028102567),
#  (140, 0.01596975591096228),
#  (141, 0.04914103787553134),
#  (142, 0.02291060170463927),
#  (143, 0.015229934549595809),
#  (144, 0.019427839299185193),
#  (145, 0.01054792074380748),
#  (146, 0.02001158188282939),
#  (147, 0.0052884068119473104),
#  (148, 0.011565502419269744),
#  (149, 0.009586301058509552),
#  (150, 0.014577365860896469),
#  (151, 0.043916954699940794),
#  (152, 0.005188576539763565),
#  (153, 0.011655592700299878),
#  (154, 0.007274828084097112),
#  (155, 0.0059933890300235635),
#  (156, 0.007658549639812133),
#  (157, 0.00763652006721948),
#  (158, 0.009439500164833458),
#  (159, 0.01531718722226294),
#  (160, 0.023510686104295762),
#  (161, 0.036531794668335484),
#  (162, 0.017833956854773996),
#  (163, 0.007725168841748013),
#  (164, 0.01558519768988351),
#  (165, 0.015055334498849349),
#  (166, 0.021146231033011293),
#  (167, 0.005463844061563414),
#  (168, 0.013723304777851745),
#  (169, 0.03979729780391131),
#  (170, 0.023268172876706922),
#  (171, 0.006954714211951131),
#  (172, 0.006278436196160119),
#  (173, 0.014351194449319924),
#  (174, 0.010258159017470965),
#  (175, 0.009378948412315374),
#  (176, 0.03566791370954799),
#  (177, 0.021958477349970397),
#  (178, 0.014813164434248297),
#  (179, 0.011177297978771678),
#  (180, 0.0056757989322023476),
#  (181, 0.014063315142166606),
#  (182, 0.006312956122208808),
#  (183, 0.007999957232643629),
#  (184, 0.023329274675970704),
#  (185, 0.009625230300446106),
#  (186, 0.020234689804807665),
#  (187, 0.021403971932895206),
#  (188, 0.013341054588552927),
#  (189, 0.010663496155235281),
#  (190, 0.017592480928659258),
#  (191, 0.017993781873968082),
#  (192, 0.03555738120694932),
#  (193, 0.009784907928705865),
#  (194, 0.010474047246603663),
#  (195, 0.015405835996791474),
#  (196, 0.010660611344768896),
#  (197, 0.07771135719674077),
#  (198, 0.007995357768086263),
#  (199, 0.009409141567189343),
#  (200, 0.01054792074380748),
#  (201, 0.017433269276721005),
#  (202, 0.012330914727785932),
#  (203, 0.022258033015939926),
#  (204, 0.011261245497008247),
#  (205, 0.015059446322379032),
#  (206, 0.010118769773681847),
#  (207, 0.02043797915995219),
#  (208, 0.014277810194926934),
#  (209, 0.033419154544657506),
#  (210, 0.018265897334167742),
#  (211, 0.015098534789104693),
#  (212, 0.011747172144141733),
#  (213, 0.14982780353026645),
#  (214, 0.09408374632612251),
#  (215, 0.06310133961061445),
#  (216, 0.01618933549522031),
#  (217, 0.030118892644758064),
#  (218, 0.018899779899900764),
#  (219, 0.008264409738687658),
#  (220, 0.021146231033011293),
#  (221, 0.011887443692289374),
#  (222, 0.01857377821614047),
#  (223, 0.017833956854773996),
#  (224, 0.02291060170463927),
#  (225, 0.01549592627782161),
#  (226, 0.011954139272339355),
#  (227, 0.016709577272328753),
#  (228, 0.01558519768988351),
#  (229, 0.016333556972523908),
#  (230, 0.025242480634975084),
#  (231, 0.014894048063556676),
#  (232, 0.021674290432295726),
#  (233, 0.010698690052788343),
#  (234, 0.012279850493429119),
#  (235, 0.009949324450977827),
#  (236, 0.022258033015939926),
#  (237, 0.006801336107062078),
#  (238, 0.4079846252828891),
#  (239, 0.005583966494903628),
#  (240, 0.010698690052788343),
#  (241, 0.008861849313751995),
#  (242, 0.017563638355373477),
#  (243, 0.004675957271812278),
#  (244, 0.005753506099533093),
#  (245, 0.017451421259872757),
#  (246, 0.017668978217953258),
#  (247, 0.008239840163134098),
#  (248, 0.0056450186852146055),
#  (249, 0.02001158188282939),
#  (250, 0.0059770696361696775),
#  (251, 0.017433269276721005),
#  (252, 0.014066050966610476),
#  (253, 0.00905724997553464),
#  (254, 0.012330914727785932),
#  (255, 0.022258033015939926),
#  (256, 0.029161450787226015),
#  (257, 0.009916048493846757),
#  (258, 0.02291060170463927),
#  (259, 0.017305897455489563),
#  (260, 0.013341054588552927),
#  (261, 0.043502834766871876),
#  (262, 0.01276529597424629),
#  (263, 0.02043797915995219),
#  (264, 0.013159384863680937),
#  (265, 0.009143149838963542),
#  (266, 0.036835398876836394),
#  (267, 0.007213380908513216),
#  (268, 0.008070837903529193),
#  (269, 0.012702182891273724),
#  (270, 0.015587505721663461),
#  (271, 0.028410770478668617),
#  (272, 0.010118769773681847),
#  (273, 0.032561031683005275),
#  (274, 0.02358707169480284),
#  (275, 0.02066415057152873),
#  (276, 0.10332075285764365),
#  (277, 0.01648793050796787),
#  (278, 0.008366299866783918),
#  (279, 0.011261245497008247),
#  (280, 0.009028910117285294),
#  (281, 0.12775804728769824),
#  (282, 0.02157914709516877),
#  (283, 0.016751899484710883),
#  (284, 0.008338779046013751),
#  (285, 0.008166778486261954),
#  (286, 0.020899949144880567),
#  (287, 0.11006497986167244),
#  (288, 0.012869243694807023),
#  (289, 0.020899949144880567),
#  (290, 0.012279850493429119),
#  (291, 0.023268172876706922),
#  (292, 0.02087495323481041),
#  (293, 0.04582120340927854),
#  (294, 0.011655592700299878),
#  (295, 0.013341054588552927),
#  (296, 0.022574715218600133),
#  (297, 0.0224382254897146),
#  (298, 0.06491741708242636),
#  (299, 0.01648793050796787),
#  (300, 0.009593839677054824),
#  (301, 0.02066415057152873),
#  (302, 0.016879033831814775),
#  (303, 0.011053714486034944),
#  (304, 0.007860859628818134),
#  (305, 0.0072954628573261345),
#  (306, 0.058847005440526026),
#  (307, 0.021146231033011293),
#  (308, 0.015680624387687088),
#  (309, 0.009439500164833458),
#  (310, 0.007814441742552766),
#  (311, 0.023268172876706922),
#  (312, 0.017059615567358837),
#  (313, 0.03353189393631503),
#  (314, 0.023999871697930882),
#  (315, 0.13434061556022206),
#  (316, 0.02066415057152873),
#  (317, 0.01907026812711754),
#  (318, 0.04002316376565878),
#  (319, 0.01907026812711754),
#  (320, 0.042292462066022586),
#  (321, 0.012983483416485272),
#  (322, 0.01531718722226294),
#  (323, 0.008363792317427853),
#  (324, 0.01217911262353548),
#  (325, 0.009409141567189343),
#  (326, 0.013856815580550776),
#  (327, 0.018734381641078407),
#  (328, 0.007336964401249949),
#  (329, 0.02066415057152873),
#  (330, 0.017059615567358837),
#  (331, 0.013528883769543077),
#  (332, 0.011958871602848538),
#  (333, 0.02291060170463927),
#  (334, 0.02291060170463927),
#  (335, 0.03213917236629206),
#  (336, 0.012869243694807023),
#  (337, 0.012540012380988714),
#  (338, 0.004326444908740224),
#  (339, 0.05229980783016302),
#  (340, 0.01950520424335509),
#  (341, 0.02291060170463927),
#  (342, 0.06348677055735252),
#  (343, 0.008414160211658361),
#  (344, 0.013789658028499555),
#  (345, 0.013657736791213137),
#  (346, 0.03486653855344201),
#  (347, 0.02784959434439425),
#  (348, 0.021153627247789242),
#  (349, 0.02798724655450454),
#  (350, 0.36386752285921853),
#  (351, 0.022258033015939926),
#  (352, 0.028410770478668617),
#  (353, 0.028853523634052865),
#  (354, 0.05943026846545203),
#  (355, 0.021958477349970397),
#  (356, 0.009409141567189343),
#  (357, 0.014133894825399911),
#  (358, 0.012486993505508207),
#  (359, 0.03814053625423508),
#  (360, 0.008944750065523274),
#  (361, 0.11466242170957312),
#  (362, 0.011013125072206371),
#  (363, 0.03461179491097913),
#  (364, 0.011013125072206371),
#  (365, 0.012330914727785932),
#  (366, 0.024062718123632802),
#  (367, 0.02073010332362516),
#  (368, 0.010585230179124286),
#  (369, 0.021958477349970397),
#  (370, 0.007792598844941755),
#  (371, 0.041076895314404914),
#  (372, 0.0384033357752173),
#  (373, 0.014577365860896469),
#  (374, 0.026559667484710378),
#  (375, 0.013041498922583397),
#  (376, 0.01531718722226294),
#  (377, 0.021674290432295726),
#  (378, 0.014577365860896469),
#  (379, 0.012229252605624298),
#  (380, 0.018879000329666915),
#  (381, 0.011887443692289374),
#  (382, 0.011013125072206371)]

# %%
#Training LDA model
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %%
# For each topic, explore the words that occur in that topic and its relative weight
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.006*"research" + 0.006*"experi" + 0.004*"human" + 0.004*"test" + 0.004*"design" + 0.004*"studi" + 0.003*"data" + 0.003*"build" + 0.003*"differ" + 0.003*"tell"
# Topic: 1
# Words: 0.013*"game" + 0.004*"life" + 0.004*"build" + 0.004*"video" + 0.004*"live" + 0.004*"play" + 0.003*"start" + 0.003*"differ" + 0.003*"develop" + 0.003*"amprsquo"
# Topic: 2
# Words: 0.007*"amprsquo" + 0.004*"build" + 0.004*"game" + 0.003*"tell" + 0.003*"facebook" + 0.003*"product" + 0.003*"user" + 0.003*"busi" + 0.003*"case" + 0.003*"servic"
# Topic: 3
# Words: 0.005*"twitter" + 0.005*"user" + 0.004*"develop" + 0.004*"technolog" + 0.004*"build" + 0.004*"facebook" + 0.004*"product" + 0.004*"chang" + 0.003*"amprsquo" + 0.003*"app"
# Topic: 4
# Words: 0.014*"game" + 0.009*"window" + 0.008*"microsoft" + 0.005*"ampmdash" + 0.005*"amprsquo" + 0.005*"googl" + 0.004*"devic" + 0.004*"experi" + 0.004*"phone" + 0.004*"user"
# Topic: 5
# Words: 0.008*"amprsquo" + 0.006*"googl" + 0.005*"phone" + 0.004*"servic" + 0.004*"game" + 0.004*"build" + 0.004*"music" + 0.004*"ampmdash" + 0.004*"call" + 0.003*"research"
# Topic: 6
# Words: 0.014*"amprsquo" + 0.008*"game" + 0.008*"microsoft" + 0.005*"appl" + 0.005*"googl" + 0.005*"ampmdash" + 0.003*"amprsquot" + 0.003*"video" + 0.003*"build" + 0.003*"chang"
# Topic: 7
# Words: 0.007*"game" + 0.005*"path" + 0.004*"data" + 0.004*"servic" + 0.003*"report" + 0.003*"user" + 0.003*"video" + 0.003*"play" + 0.003*"group" + 0.003*"tell"
# Topic: 8
# Words: 0.006*"amprsquo" + 0.006*"googl" + 0.005*"servic" + 0.003*"user" + 0.003*"technolog" + 0.003*"ampmdash" + 0.003*"video" + 0.003*"million" + 0.003*"product" + 0.003*"drive"
# Topic: 9
# Words: 0.008*"research" + 0.007*"amprsquo" + 0.007*"studi" + 0.006*"ampmdash" + 0.005*"cell" + 0.004*"scientist" + 0.004*"diseas" + 0.004*"appl" + 0.004*"chang" + 0.003*"drug"

# %%
#LDA using TF-IDF
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.007*"amprsquo" + 0.005*"game" + 0.004*"window" + 0.004*"microsoft" + 0.003*"ampmdash" + 0.003*"amazon" + 0.003*"amprsquot" + 0.002*"twitter" + 0.002*"amprdquo" + 0.002*"attack"
# Topic: 1 Word: 0.007*"microsoft" + 0.004*"xbox" + 0.004*"amprsquo" + 0.004*"appl" + 0.003*"window" + 0.002*"game" + 0.002*"youtub" + 0.002*"oculus" + 0.002*"robot" + 0.002*"consol"
# Topic: 2 Word: 0.003*"game" + 0.003*"facebook" + 0.003*"googl" + 0.002*"amprsquo" + 0.002*"photo" + 0.002*"appl" + 0.002*"ampmdash" + 0.002*"user" + 0.002*"phone" + 0.002*"bitcoin"
# Topic: 3 Word: 0.006*"amprsquo" + 0.003*"cell" + 0.003*"game" + 0.003*"patient" + 0.003*"ampmdash" + 0.002*"drone" + 0.002*"drug" + 0.002*"amprsquot" + 0.002*"research" + 0.002*"treatment"
# Topic: 4 Word: 0.003*"amprsquo" + 0.002*"planet" + 0.002*"genom" + 0.002*"studi" + 0.002*"game" + 0.002*"ampmdash" + 0.002*"data" + 0.002*"water" + 0.002*"facebook" + 0.002*"speci"
# Topic: 5 Word: 0.003*"game" + 0.002*"amphellip" + 0.002*"ampmdash" + 0.002*"infect" + 0.002*"film" + 0.002*"genet" + 0.002*"drone" + 0.002*"read" + 0.002*"drug" + 0.002*"amprsquo"
# Topic: 6 Word: 0.004*"amphellip" + 0.002*"read" + 0.002*"children" + 0.002*"bird" + 0.002*"continu" + 0.002*"cabl" + 0.002*"game" + 0.002*"twitter" + 0.002*"appl" + 0.002*"batteri"
# Topic: 7 Word: 0.003*"game" + 0.003*"music" + 0.002*"robot" + 0.002*"amprsquo" + 0.002*"machin" + 0.002*"youtub" + 0.002*"amphellip" + 0.002*"copyright" + 0.001*"read" + 0.001*"googl"
# Topic: 8 Word: 0.004*"microsoft" + 0.003*"gene" + 0.002*"game" + 0.002*"googl" + 0.002*"film" + 0.002*"disney" + 0.002*"research" + 0.002*"bitcoin" + 0.002*"window" + 0.002*"organ"
# Topic: 9 Word: 0.002*"film" + 0.002*"uber" + 0.002*"amprsquo" + 0.002*"game" + 0.002*"polic" + 0.002*"comcast" + 0.002*"chip" + 0.002*"spotifi" + 0.002*"card" + 0.002*"phone"

# %%
#Getting the category of the first article

# print(processed_docs[0]) #This is the article
for index, score in sorted(lda_model[bow_corpus[0]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# The topic with the highest score/probability is the topic most likely associated
# with it
# Out:
# Score: 0.9987696409225464
# Topic: 0.013*"game" + 0.004*"life" + 0.004*"build" + 0.004*"video" + 0.004*"live" + 0.004*"play" + 0.003*"start" + 0.003*"differ" + 0.003*"develop" + 0.003*"amprsquo"

# %%
#Getting the topic of the first article with the LDA TF-IDF model
for index, score in sorted(lda_model_tfidf[bow_corpus[0]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.8024715185165405
# Topic: 0.003*"game" + 0.003*"facebook" + 0.003*"googl" + 0.002*"amprsquo" + 0.002*"photo" + 0.002*"appl" + 0.002*"ampmdash" + 0.002*"user" + 0.002*"phone" + 0.002*"bitcoin"
#
# Score: 0.12606246769428253
# Topic: 0.003*"game" + 0.002*"amphellip" + 0.002*"ampmdash" + 0.002*"infect" + 0.002*"film" + 0.002*"genet" + 0.002*"drone" + 0.002*"read" + 0.002*"drug" + 0.002*"amprsquo"
#
# Score: 0.03714098781347275
# Topic: 0.003*"amprsquo" + 0.002*"planet" + 0.002*"genom" + 0.002*"studi" + 0.002*"game" + 0.002*"ampmdash" + 0.002*"data" + 0.002*"water" + 0.002*"facebook" + 0.002*"speci"
#
# Score: 0.028198009356856346
# Topic: 0.007*"amprsquo" + 0.005*"game" + 0.004*"window" + 0.004*"microsoft" + 0.003*"ampmdash" + 0.003*"amazon" + 0.003*"amprsquot" + 0.002*"twitter" + 0.002*"amprdquo" + 0.002*"attack"
